# %%
import os
import sys
import json
import numpy as np
import pandas as pd
import cobra
from cobra.flux_analysis import flux_variability_analysis
import pysvg
from tempfile import mkstemp
from shutil import move
from os import remove

# %%
model=cobra.io.load_json_model('iML1515.json')

# %%
sol=model.optimize()
sol.fluxes=sol.fluxes.round(5)
reac_id=[]
for s in model.reactions:
        reac_id.append(s.id)

# %%
fva_results=flux_variability_analysis(model, fraction_of_optimum=0.5)
fva_results=fva_results.round(2)

# %% [markdown]
# Open dialog for network layout file

# %%
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

## file_source_path = tkFileDialog.askopenfilename()        ## python 2.x
file_source_path=tk.filedialog.askopenfilename()

# %%
try:
    # for Python2
    import Tkinter as tk
    from tkinter import tkFileDialog
    
    root = tk.Tk()
    root.withdraw()
    file_source_path = tkFileDialog.askopenfilename()
    
except ImportError:
    
    # for Python3
    import tkinter as tk
    from tkinter import filedialog
    
    root = tk.Tk()
    root.withdraw()
    file_source_path=tk.filedialog.askopenfilename()

# %% [markdown]
# Call_Vizan init variables, parameters

# %%
##file_source_path='E_coli_source.svg'
SolutionAnalysis= sol##fva_results  ##sol
SolutionType= 'FBA' ##'FVA'##'FBA'              ### 'EM' 'FBA'
prod='prod'
subst='subst'
count='0'

# %% [markdown]
# Override for pysvg function

# %%
from xml.dom import minidom
from xml.dom import Node
from pysvg.animate import *
from pysvg.filter import *
from pysvg.gradient import *
from pysvg.linking import *
from pysvg.script import *
from pysvg.shape import *
from pysvg.structure import *
from pysvg.style import *
from pysvg.text import *

def calculateMethodName(attr):
    name=attr
    name=name.replace(':','_')
    name=name.replace('-','_')
    name='set_'+name
    return name
    
def setAttributes(attrs,obj):
    for attr in attrs.keys():
        if hasattr(obj, calculateMethodName(attr)):
            eval ('obj.'+calculateMethodName(attr))(attrs[attr].value)
        
def build2(node_, object):
    attrs = node_.attributes
   
    if attrs != None:
        setAttributes(attrs, object)
        
    for child_ in node_.childNodes:
        nodeName_ = child_.nodeName.split(':')[-1]
        if child_.nodeType == Node.ELEMENT_NODE:
            try:
                objectinstance=eval(nodeName_.title()) ()                
            except:
                continue
            object.addElement(build2(child_,objectinstance))
        elif child_.nodeType == Node.TEXT_NODE:
            if child_.nodeValue != None:
                object.appendTextContent(child_.nodeValue)
        elif child_.nodeType == Node.CDATA_SECTION_NODE:  
            object.appendTextContent('<![CDATA['+child_.nodeValue+']]>')          
        elif child_.nodeType == Node.COMMENT_NODE:  
            object.appendTextContent('<!-- '+child_.nodeValue+' -->')          
        else:
            continue
            
    return object

def parse2(inFileName):
    doc = minidom.parse(inFileName)
    rootNode = doc.documentElement
    rootObj = pysvg.structure.Svg()
    build2(rootNode,rootObj)
    doc = None
    return rootObj

# %%
def Call_Vizan(model,file_source_path,SolutionAnalysis,SolutionType,prod,subst,count):
##    SVGObject=parser.parse(path)
    SVGObject=parse2(file_source_path)
    if type(SolutionAnalysis) == cobra.core.solution.Solution:
        flux_sum=calculate_common_substrate_flux()
    else:
        flux_sum=0

    print('---------------------')
    for s in SVGObject._subElements:
        #str(s.__class__) <> 'core.TextContent':
        if not isinstance(s, pysvg.core.TextContent):
            print ( 'viens')
            if isinstance(s, pysvg.structure.G): #str(s.__class__) == 'structure.g':
                for s1 in s._subElements:                      
                    #if str(s1.__class__) != 'core.TextContent':
                    if not isinstance(s1, pysvg.core.TextContent):
                        print (s1.getAttribute('class'), s1.getAttribute('id'),'divi')
                        set_reaction_id_from_sympheny(s1,' ',d=0)                       ## to put ID on reaction class group elements
                        set_metabolite_id_from_sympheny(s1,' ',d=0)                     ## to put ID on metabolite class group elements
                        TravSVGFBA(s1,model,SolutionAnalysis,'',flux_sum,0)              ## for calculating colors and etc
    SVGObject.save('pysvg_developed_file.svg')
    ##SVGObject.save(str(prod) + "_" + str(subst) + "_" + str(count) + '.svg')  
#    SVGObject=parse2(path) 
    ##pysvg_developed_file
    print ('Network has been drawn')
    
def TravSVG2(svgobj, action=lambda obj, d:(obj,d), d=0):
    action(svgobj,d)
    if hasattr(svgobj,"_subElements"):
        for sel in svg._subElements:
            TravSvg2(sel, action, d+1)

class Style2(dict):
    def __init__(self, instr=""):
        for kv in instr.split(";"):
            if kv != '':
                k,v = kv.split(":")
                self[k.strip()]  = v.strip()
         
    def changeColorText(self,color,attr):		## not only color but also attribute property
        for k in self:
            if k==attr:
                self[k.strip()]=color

    def __str__ (self):
        rv = ""
        for k in self:
            rv += k +":" + self[k] + ";"
        return str(rv)

    
def TravSVGFBA (svgobj,model,SolutionAnalysis,Reac,flux_sum,d=0):		
        print ('tris') ##print 'd mees izmantojam', len(element), len(svgobj._subElements), d, svgobj.__class__
        for s in svgobj._subElements:				        
            if not isinstance(s, pysvg.core.TextContent):
                if str(s.getAttribute('class')) == 'reaction' and s.getAttribute('id') in reac_id:						              
                    Reac=str(s.getAttribute('id'))
                    info_reac=model.reactions.get_by_id(Reac)  
                    s.setAttribute(attribute_name='Name',attribute_value=info_reac.name)    
                    s.setAttribute(attribute_name='Stoichiometry',attribute_value=info_reac.reaction)    
                    s.setAttribute(attribute_name='GPR',attribute_value=str(info_reac.gene_reaction_rule))    
                    s.setAttribute(attribute_name='Lower_bound',attribute_value=str(info_reac.lower_bound))
                    s.setAttribute(attribute_name='Upper_bound',attribute_value=str(info_reac.upper_bound))
                    TravSVGFBA(s,model,SolutionAnalysis,Reac,flux_sum,d+1)
##                else: 
##                    print 'no reactions', s.getAttribute('id'), s.getAttribute('class')
                if str(s.getAttribute('class')) == 'segment-group' or s.getAttribute('class') == 'arrowheads' or str(s.getAttribute('class')) == 'reaction-label-group':
                    TravSVGFBA(s,model,SolutionAnalysis,Reac,flux_sum,d+1)       
                if str(s.getAttribute('class')) == 'segment' and Reac in reac_id:
                    setColorSVGFBA(s,Reac,SolutionAnalysis,'stroke',flux_sum) 
                if str(s.getAttribute('class')) == 'arrowhead' and Reac in reac_id:
                    setColorSVGFBA(s,Reac,SolutionAnalysis,'fill',flux_sum) 
                if str(s.getAttribute('class')) == 'reaction-label label' and Reac in reac_id:
                    for l in s._subElements:
##                        print str(l.__class__)
                        #if str(l.__class__) == 'core.TextContent':
                        if isinstance(l, pysvg.core.TextContent): 
##                            print dir(l)
                            if type(SolutionAnalysis) == cobra.core.solution.Solution:
                                l.setContent(Reac + ' ' + str(SolutionAnalysis[Reac])) ### FVA variantu vajag
    ##                            print Reac, str(l.content) ,'veertiiba'
                            if type(SolutionAnalysis) == pd.core.frame.DataFrame:
                                l.setContent(Reac + ' ' + str(SolutionAnalysis.loc[Reac,'minimum']) + ' ' + str(SolutionAnalysis.loc[Reac,'maximum']))
                if str(s.getAttribute('class')) == 'node':
                    Metab=s.getAttribute('id_cobrapy')
                    print (Metab, s.getAttribute('id'),s.getAttribute('id_cobrapy'))
                    info_metab=model.metabolites.get_by_id(Metab)
                    s.setAttribute(attribute_name='Charge',attribute_value=info_metab.charge)    
                    s.setAttribute(attribute_name='Compartment',attribute_value=info_metab.compartment) 
                    s.setAttribute(attribute_name='Elements',attribute_value=info_metab.elements) 
                    s.setAttribute(attribute_name='Formula',attribute_value=info_metab.formula) 
                    s.setAttribute(attribute_name='Name',attribute_value=info_metab.name) 
                    s.setAttribute(attribute_name='Shadow_price',attribute_value=info_metab.shadow_price) 
                    TravSVGFBA(s,model,SolutionAnalysis,Reac,flux_sum,d+1)
                if str(s.getAttribute('class')) == 'node-circle metabolite-circle':
                    print ("")
##                if str(s.getAttribute('class')) == 'node-label label':
##                    for l in s._subElements:
##                        print l.content, 'metabolitu teksts' 
    


def setColorSVGFBA(svgobj,Reac,SolutionAnalysis,color_type,flux_sum):	
    styleText = Style2(str(svgobj.getAttribute('style')))
##    print dir(styleText)
##    print svgobj.getAttribute('style')
    if type(SolutionAnalysis)==cobra.core.solution.Solution:
        if SolutionAnalysis[Reac] > 0:
            styleText.changeColorText('#008000',color_type)
        elif SolutionAnalysis[Reac] < 0:
            styleText.changeColorText('#d40000',color_type)
        else:
            styleText.changeColorText('#808000',color_type)
        ##else:
            ##styleText.changeColorText('#808000')
        if color_type == 'stroke':
            styleText.changeColorText(color=set_stroke_line_width_FBA(SolutionAnalysis,Reac,flux_sum),attr='stroke-width')
    ##    set_stoke_line_width
    if type(SolutionAnalysis) == pd.core.frame.DataFrame:
        styleText.changeColorText(color=set_stroke_line_width_FVA(SolutionAnalysis,Reac),attr='stroke-width')
        if SolutionAnalysis.loc[Reac,'maximum']>0 and SolutionAnalysis.loc[Reac,'minimum'] >= 0: ## pozitīvs !!
            styleText.changeColorText('#008000',color_type)
        if SolutionAnalysis.loc[Reac,'maximum']>0 and SolutionAnalysis.loc[Reac,'minimum'] < 0: ## abpusejs
            styleText.changeColorText('#0024ff',color_type)
        if SolutionAnalysis.loc[Reac,'maximum']< 0 and SolutionAnalysis.loc[Reac,'minimum'] < 0: ## negativs !!
            styleText.changeColorText('#d40000',color_type)
        if SolutionAnalysis.loc[Reac,'maximum']==0 and SolutionAnalysis.loc[Reac,'minimum'] == 0: ## nulee    
            styleText.changeColorText('#000000',color_type)
        if color_type == 'stroke':
            styleText.changeColorText(color=set_stroke_line_width_FVA(SolutionAnalysis,Reac),attr='stroke-width')
    ##    set_stoke_line_width
    svgobj.setAttribute('style',str(styleText.__str__()))

############################Read from text label rxn id and put it as group id
    
    
def set_reaction_id_from_sympheny(svgobj, Reac=' ',d=0):
        for s in svgobj._subElements:				  
            #if str(s.__class__) != 'core.TextContent':  
            if not isinstance(s, pysvg.core.TextContent):
                if str(s.getAttribute('class')) == 'reaction':
                    Reac=set_reaction_id_from_sympheny(s, Reac,d+1)
                    ##print Reac, 'reakcijas teksts'         
                    if Reac != ' ' and d==0:
##                        print 'tests'                        
                        name,reac_value = Reac.split(' ')
                        s.setAttribute(attribute_name='id',attribute_value=name)  
                if str(s.getAttribute('class')) == 'reaction-label-group':
                    Reac=set_reaction_id_from_sympheny(s, Reac,d+1)
                if str(s.getAttribute('class')) == 'reaction-label label':
                    for l in s._subElements:
#                        if str(l.__class__) == 'core.TextContent':
                        if isinstance(l, pysvg.core.TextContent):
                            Reac=str(l.content)
        return Reac
    
    
def set_metabolite_id_from_sympheny(svgobj, Metab=' ',d=0):
        for s in svgobj._subElements:				  
            #if str(s) != 'core.TextContent':
            if not isinstance(s, pysvg.core.TextContent):
##                print s.getAttribute('id'), s.getAttribute('class')  
##                print Metab, 'metabolitu teksts'
                if str(s.getAttribute('class')) == 'node':
                    Metab=set_metabolite_id_from_sympheny(s, Metab,d+1)
##                    print Metab, 'metabolitu teksts'         
                    if Metab != ' ' and d==0:
##                        print Metab, 'definejam id'
                        s.setAttribute(attribute_name='id_cobrapy',attribute_value=Metab)  
##                        print s.getAttribute('id')
##                if str(s.getAttribute('class')) == 'node':
##                    Metab=set_metabolite_id_from_sympheny(s, Metab,d+1)
                if str(s.getAttribute('class')) == 'node-label label':
                    for l in s._subElements:
                        if isinstance(l, pysvg.core.TextContent): #str(l.__class__) == 'core.TextContent': 
                            Metab=str(l.content)
                            Metab=Metab[0:]
        return Metab
    
    
def calculate_common_substrate_flux():
    from cobra.flux_analysis.variability import flux_variability_analysis
    boundary_reactions = model.exchanges
    ##### generate model exchange reactions#####################

    fva_results = flux_variability_analysis(
                    model, reaction_list=boundary_reactions,
                    fraction_of_optimum=1)
    #### Generate FVA results   ###############################################


    fva_results=fva_results.sort_values(by='minimum', ascending=True)


    ### sort FVA results ascending order###


##    if SolutionAnalysis == ''
    substrates = fva_results['minimum'] < 0
    fva_results_substrates=fva_results[substrates].sort_values(by='minimum', ascending=True)

    #####   Generate dataframe where only consuming reactions are taken into account   #####


    reac_consist_carbon=[]
    for reaction in fva_results_substrates.index:
        reac_cobrapy=model.reactions.get_by_id(reaction)
        for metabolite in reac_cobrapy.reactants:
            if 'C' in metabolite.elements.keys():
                reac_consist_carbon.append(str(reaction))


    ###### Filter from FVA substrate list reactions which HAVE NOT included 


    ##print reac_consist_carbon
    flux_sum=0
    for reaction in reac_consist_carbon:
        print (fva_results.loc[reaction])
        flux_sum=flux_sum + fva_results.loc[reaction,'minimum']
    print (flux_sum)
    return flux_sum
    ##print fva_results


    ##### calculate flux sum how much is consumed all substrates (not taking into account carbon amount for each substrate)
    ## to do is take into account substrate carbon ratio for better flux calculation
    
    
    
def set_stroke_line_width_FBA(SolutionAnalysis,Reac,flux_sum):
    Solution=abs(SolutionAnalysis[Reac])
    flux_sum=abs(flux_sum)
    print (Reac, Solution, flux_sum, Solution>flux_sum)
    if Solution>= flux_sum * 0.7 :
        width = 21
    if Solution >= flux_sum * 0.5 and Solution < flux_sum * 0.7:
        width = 20
    if Solution >= flux_sum * 0.3 and Solution < flux_sum * 0.5:
        width = 18
    if Solution >= flux_sum * 0.2 and Solution < flux_sum * 0.3:
        width = 16
    if Solution >= flux_sum * 0.1 and Solution < flux_sum * 0.2:
        width = 13
    if Solution >= 0 and Solution < flux_sum * 0.1:
        width = 4
    #if SolutionAnalysis = 0:
#        width = 4
    return str(width)

def set_stroke_line_width_FVA(SolutionAnalysis,Reac):
##    max_diapazon=abs(SolutionAnalysis.max().loc['maximum']) + abs(SolutionAnalysis.max().loc['minimum']) ## kaut ko gudraaku vajag
    max_diapazon=100
    flux_diapasone=0
    if SolutionAnalysis.loc[Reac,'maximum'] > 0 or SolutionAnalysis.loc[Reac,'maximum']== SolutionAnalysis.loc[Reac,'minimum']:   
        flux_diapasone=SolutionAnalysis.loc[Reac,'maximum']-SolutionAnalysis.loc[Reac,'minimum']
    if SolutionAnalysis.loc[Reac,'maximum'] < 0:
        flux_diapasone=abs(SolutionAnalysis.loc[Reac,'maximum']+SolutionAnalysis.loc[Reac,'minimum'])
##    flux_diapasone=abs(SolutionAnalysis.loc[Reac,'maximum']) + abs(SolutionAnalysis.loc[Reac,'minimum'])
    print (Reac, max_diapazon, flux_diapasone, SolutionAnalysis.loc[Reac,'maximum'], SolutionAnalysis.loc[Reac,'minimum'])
    if flux_diapasone>= max_diapazon * 0.5 and flux_diapasone < max_diapazon or flux_diapasone > max_diapazon:
        width = 24
    if flux_diapasone >= max_diapazon * 0.25 and flux_diapasone < max_diapazon * 0.5:
        width = 20
    if flux_diapasone >= max_diapazon * 0.13 and flux_diapasone < max_diapazon * 0.25:
        width = 16
    if flux_diapasone >= max_diapazon * 0.05  and flux_diapasone < max_diapazon * 0.13:
        width = 12
    if flux_diapasone >= max_diapazon * 0.0 and flux_diapasone < max_diapazon * 0.05:
        width = 8
    print (width)
    return str(width)

# %% [markdown]
# ## Get total flux ammount for stroke function

# %%
Call_Vizan(model,file_source_path,SolutionAnalysis,SolutionType,prod,subst,count)
# Out:
# minimum   -10.0
# maximum   -10.0
# Name: EX_glc__D_e, dtype: float64
# minimum   -9.948599e-16
# maximum   -8.216191e-15
# Name: EX_hacolipa_e, dtype: float64
# minimum   -8.501492e-18
# maximum   -2.583597e-14
# Name: EX_spmd_e, dtype: float64
# -10.0
# ---------------------
# viens
# viens
# None style2 divi
# tris
# viens
# canvas-group g12 divi
# tris
# None brush-container divi
# tris
# None reactions divi
# tris
# tris
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# MDH 6.88459 10.0 False
# tris
# tris
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# NTRIR3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# NADPHQR4 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# NADH17pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# MALt3pp 0.0 10.0 False
# tris
# tris
# MALt3pp 0.0 10.0 False
# tris
# tris
# MALt3pp 0.0 10.0 False
# tris
# tris
# MALt3pp 0.0 10.0 False
# tris
# tris
# MALt3pp 0.0 10.0 False
# tris
# tris
# MALt3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# D_LACt2pp 0.0 10.0 False
# tris
# tris
# D_LACt2pp 0.0 10.0 False
# tris
# tris
# D_LACt2pp 0.0 10.0 False
# tris
# tris
# D_LACt2pp 0.0 10.0 False
# tris
# tris
# D_LACt2pp 0.0 10.0 False
# tris
# tris
# D_LACt2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# G1PPpp 0.0 10.0 False
# tris
# tris
# G1PPpp 0.0 10.0 False
# tris
# tris
# G1PPpp 0.0 10.0 False
# tris
# tris
# G1PPpp 0.0 10.0 False
# tris
# tris
# G1PPpp 0.0 10.0 False
# tris
# tris
# G1PPpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACONMT 0.0 10.0 False
# tris
# tris
# ACONMT 0.0 10.0 False
# tris
# tris
# ACONMT 0.0 10.0 False
# tris
# tris
# ACONMT 0.0 10.0 False
# tris
# tris
# ACONMT 0.0 10.0 False
# tris
# tris
# ACONMT 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACALDtex 0.0 10.0 False
# tris
# tris
# ACALDtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYCTO3 0.0 10.0 False
# tris
# tris
# GLYCTO3 0.0 10.0 False
# tris
# tris
# GLYCTO3 0.0 10.0 False
# tris
# tris
# GLYCTO3 0.0 10.0 False
# tris
# tris
# GLYCTO3 0.0 10.0 False
# tris
# tris
# GLYCTO3 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACONIs 0.0 10.0 False
# tris
# tris
# ACONIs 0.0 10.0 False
# tris
# tris
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# CYTBD2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# PPC 2.59611 10.0 False
# tris
# tris
# tris
# tris
# F6Ptex 0.0 10.0 False
# tris
# tris
# F6Ptex 0.0 10.0 False
# tris
# tris
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# MALS 0.0 10.0 False
# tris
# tris
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# HYD3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FBA3 0.0 10.0 False
# tris
# tris
# FBA3 0.0 10.0 False
# tris
# tris
# FBA3 0.0 10.0 False
# tris
# tris
# FBA3 0.0 10.0 False
# tris
# tris
# tris
# tris
# ETOHtrpp 0.0 10.0 False
# tris
# tris
# ETOHtrpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# CYTBDpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FUMt2_2pp 0.0 10.0 False
# tris
# tris
# FUMt2_2pp 0.0 10.0 False
# tris
# tris
# FUMt2_2pp 0.0 10.0 False
# tris
# tris
# FUMt2_2pp 0.0 10.0 False
# tris
# tris
# FUMt2_2pp 0.0 10.0 False
# tris
# tris
# FUMt2_2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCP 0.0 10.0 False
# tris
# tris
# GLCP 0.0 10.0 False
# tris
# tris
# GLCP 0.0 10.0 False
# tris
# tris
# GLCP 0.0 10.0 False
# tris
# tris
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# NO3R2bpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# NADH18pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# DSBAO1 0.0 10.0 False
# tris
# tris
# DSBAO1 0.0 10.0 False
# tris
# tris
# DSBAO1 0.0 10.0 False
# tris
# tris
# DSBAO1 0.0 10.0 False
# tris
# tris
# DSBAO1 0.0 10.0 False
# tris
# tris
# DSBAO1 0.0 10.0 False
# tris
# tris
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# TMAOR2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# CS 6.913 10.0 False
# tris
# tris
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# GLGC 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYCtpp 0.0 10.0 False
# tris
# tris
# GLYCtpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYCTO4 0.0 10.0 False
# tris
# tris
# GLYCTO4 0.0 10.0 False
# tris
# tris
# GLYCTO4 0.0 10.0 False
# tris
# tris
# GLYCTO4 0.0 10.0 False
# tris
# tris
# GLYCTO4 0.0 10.0 False
# tris
# tris
# GLYCTO4 0.0 10.0 False
# tris
# tris
# tris
# tris
# PGI 7.64463 10.0 False
# tris
# tris
# PGI 7.64463 10.0 False
# tris
# tris
# tris
# tris
# GLYCtex 0.0 10.0 False
# tris
# tris
# GLYCtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# QMO3 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# GLYOX 0.0 10.0 False
# tris
# tris
# tris
# tris
# PGK 17.10543 10.0 True
# tris
# tris
# PGK 17.10543 10.0 True
# tris
# tris
# PGK 17.10543 10.0 True
# tris
# tris
# PGK 17.10543 10.0 True
# tris
# tris
# PGK 17.10543 10.0 True
# tris
# tris
# PGK 17.10543 10.0 True
# tris
# tris
# tris
# tris
# FUMtex 0.0 10.0 False
# tris
# tris
# FUMtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# CAT 0.0 10.0 False
# tris
# tris
# CAT 0.0 10.0 False
# tris
# tris
# CAT 0.0 10.0 False
# tris
# tris
# CAT 0.0 10.0 False
# tris
# tris
# tris
# tris
# ETOHtex 0.0 10.0 False
# tris
# tris
# ETOHtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# H2tpp 0.0 10.0 False
# tris
# tris
# H2tpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# SPODMpp 0.0 10.0 False
# tris
# tris
# SPODMpp 0.0 10.0 False
# tris
# tris
# SPODMpp 0.0 10.0 False
# tris
# tris
# SPODMpp 0.0 10.0 False
# tris
# tris
# SPODMpp 0.0 10.0 False
# tris
# tris
# SPODMpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# G3PD5 0.0 10.0 False
# tris
# tris
# G3PD5 0.0 10.0 False
# tris
# tris
# G3PD5 0.0 10.0 False
# tris
# tris
# G3PD5 0.0 10.0 False
# tris
# tris
# G3PD5 0.0 10.0 False
# tris
# tris
# G3PD5 0.0 10.0 False
# tris
# tris
# tris
# tris
# PGMT 0.0 10.0 False
# tris
# tris
# PGMT 0.0 10.0 False
# tris
# tris
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# G6PDH2r 2.35537 10.0 False
# tris
# tris
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# ACS 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# GLYK 0.0 10.0 False
# tris
# tris
# tris
# tris
# AKGt2rpp 0.0 10.0 False
# tris
# tris
# AKGt2rpp 0.0 10.0 False
# tris
# tris
# AKGt2rpp 0.0 10.0 False
# tris
# tris
# AKGt2rpp 0.0 10.0 False
# tris
# tris
# AKGt2rpp 0.0 10.0 False
# tris
# tris
# AKGt2rpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# MALt2_2pp 0.0 10.0 False
# tris
# tris
# MALt2_2pp 0.0 10.0 False
# tris
# tris
# MALt2_2pp 0.0 10.0 False
# tris
# tris
# MALt2_2pp 0.0 10.0 False
# tris
# tris
# MALt2_2pp 0.0 10.0 False
# tris
# tris
# MALt2_2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# PGL 2.35537 10.0 False
# tris
# tris
# PGL 2.35537 10.0 False
# tris
# tris
# PGL 2.35537 10.0 False
# tris
# tris
# PGL 2.35537 10.0 False
# tris
# tris
# PGL 2.35537 10.0 False
# tris
# tris
# PGL 2.35537 10.0 False
# tris
# tris
# tris
# tris
# 12PPDRtpp 0.0 10.0 False
# tris
# tris
# 12PPDRtpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# DMSOtpp 0.0 10.0 False
# tris
# tris
# DMSOtpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# ATPS4rpp 70.43249 10.0 True
# tris
# tris
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# NADH16pp 37.99704 10.0 True
# tris
# tris
# tris
# tris
# ACKr 0.51058 10.0 False
# tris
# tris
# ACKr 0.51058 10.0 False
# tris
# tris
# ACKr 0.51058 10.0 False
# tris
# tris
# ACKr 0.51058 10.0 False
# tris
# tris
# ACKr 0.51058 10.0 False
# tris
# tris
# ACKr 0.51058 10.0 False
# tris
# tris
# tris
# tris
# GLDBRAN2 0.0 10.0 False
# tris
# tris
# GLDBRAN2 0.0 10.0 False
# tris
# tris
# tris
# tris
# RPI 1.43046 10.0 False
# tris
# tris
# RPI 1.43046 10.0 False
# tris
# tris
# tris
# tris
# XYLt2pp 0.0 10.0 False
# tris
# tris
# XYLt2pp 0.0 10.0 False
# tris
# tris
# XYLt2pp 0.0 10.0 False
# tris
# tris
# XYLt2pp 0.0 10.0 False
# tris
# tris
# XYLt2pp 0.0 10.0 False
# tris
# tris
# XYLt2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# G1Ptex 0.0 10.0 False
# tris
# tris
# G1Ptex 0.0 10.0 False
# tris
# tris
# tris
# tris
# MALtex 0.0 10.0 False
# tris
# tris
# MALtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# CYTBO3_4pp 44.25629 10.0 True
# tris
# tris
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# DMSOR1pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FRUptspp 0.0 10.0 False
# tris
# tris
# FRUptspp 0.0 10.0 False
# tris
# tris
# FRUptspp 0.0 10.0 False
# tris
# tris
# FRUptspp 0.0 10.0 False
# tris
# tris
# FRUptspp 0.0 10.0 False
# tris
# tris
# FRUptspp 0.0 10.0 False
# tris
# tris
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# PYK 2.27581 10.0 False
# tris
# tris
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# QMO2 0.00342 10.0 False
# tris
# tris
# tris
# tris
# L_LACt2rpp 0.0 10.0 False
# tris
# tris
# L_LACt2rpp 0.0 10.0 False
# tris
# tris
# L_LACt2rpp 0.0 10.0 False
# tris
# tris
# L_LACt2rpp 0.0 10.0 False
# tris
# tris
# L_LACt2rpp 0.0 10.0 False
# tris
# tris
# L_LACt2rpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# NADH10 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# GLYCDx 0.0 10.0 False
# tris
# tris
# tris
# tris
# MALt2_3pp 0.0 10.0 False
# tris
# tris
# MALt2_3pp 0.0 10.0 False
# tris
# tris
# MALt2_3pp 0.0 10.0 False
# tris
# tris
# MALt2_3pp 0.0 10.0 False
# tris
# tris
# MALt2_3pp 0.0 10.0 False
# tris
# tris
# MALt2_3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# DHAPT 0.0 10.0 False
# tris
# tris
# DHAPT 0.0 10.0 False
# tris
# tris
# DHAPT 0.0 10.0 False
# tris
# tris
# DHAPT 0.0 10.0 False
# tris
# tris
# DHAPT 0.0 10.0 False
# tris
# tris
# DHAPT 0.0 10.0 False
# tris
# tris
# tris
# tris
# CO2tex 24.00329 10.0 True
# tris
# tris
# CO2tex 24.00329 10.0 True
# tris
# tris
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# NO3R1bpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# DSBAO2 0.0 10.0 False
# tris
# tris
# DSBAO2 0.0 10.0 False
# tris
# tris
# DSBAO2 0.0 10.0 False
# tris
# tris
# DSBAO2 0.0 10.0 False
# tris
# tris
# DSBAO2 0.0 10.0 False
# tris
# tris
# DSBAO2 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# GLYC3Pabcpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# PPCK 0.0 10.0 False
# tris
# tris
# tris
# tris
# L_LACtex 0.0 10.0 False
# tris
# tris
# L_LACtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# PDH 9.68969 10.0 False
# tris
# tris
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# ME2 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACALDtpp 0.0 10.0 False
# tris
# tris
# ACALDtpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FRUtex 0.0 10.0 False
# tris
# tris
# FRUtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# XYLabcpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FRD3 0.0 10.0 False
# tris
# tris
# FRD3 0.0 10.0 False
# tris
# tris
# FRD3 0.0 10.0 False
# tris
# tris
# FRD3 0.0 10.0 False
# tris
# tris
# FRD3 0.0 10.0 False
# tris
# tris
# FRD3 0.0 10.0 False
# tris
# tris
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# PPA2 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACt2rpp 0.00456 10.0 False
# tris
# tris
# ACt2rpp 0.00456 10.0 False
# tris
# tris
# ACt2rpp 0.00456 10.0 False
# tris
# tris
# ACt2rpp 0.00456 10.0 False
# tris
# tris
# ACt2rpp 0.00456 10.0 False
# tris
# tris
# ACt2rpp 0.00456 10.0 False
# tris
# tris
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# HYD2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# POX 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# NADPHQR2 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACONTb 6.913 10.0 False
# tris
# tris
# ACONTb 6.913 10.0 False
# tris
# tris
# ACONTb 6.913 10.0 False
# tris
# tris
# ACONTb 6.913 10.0 False
# tris
# tris
# tris
# tris
# CITtex 0.0 10.0 False
# tris
# tris
# CITtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# RIBabcpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FUM 6.88459 10.0 False
# tris
# tris
# FUM 6.88459 10.0 False
# tris
# tris
# FUM 6.88459 10.0 False
# tris
# tris
# FUM 6.88459 10.0 False
# tris
# tris
# tris
# tris
# EDA 0.0 10.0 False
# tris
# tris
# EDA 0.0 10.0 False
# tris
# tris
# EDA 0.0 10.0 False
# tris
# tris
# EDA 0.0 10.0 False
# tris
# tris
# tris
# tris
# PFL 0.0 10.0 False
# tris
# tris
# PFL 0.0 10.0 False
# tris
# tris
# PFL 0.0 10.0 False
# tris
# tris
# PFL 0.0 10.0 False
# tris
# tris
# PFL 0.0 10.0 False
# tris
# tris
# PFL 0.0 10.0 False
# tris
# tris
# tris
# tris
# PPA 3.07086 10.0 False
# tris
# tris
# PPA 3.07086 10.0 False
# tris
# tris
# PPA 3.07086 10.0 False
# tris
# tris
# PPA 3.07086 10.0 False
# tris
# tris
# PPA 3.07086 10.0 False
# tris
# tris
# PPA 3.07086 10.0 False
# tris
# tris
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# NO3R1pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCP2 0.0 10.0 False
# tris
# tris
# GLCP2 0.0 10.0 False
# tris
# tris
# GLCP2 0.0 10.0 False
# tris
# tris
# GLCP2 0.0 10.0 False
# tris
# tris
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# TMAOR1pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# NADH5 0.0 10.0 False
# tris
# tris
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# LDH_D 0.0 10.0 False
# tris
# tris
# tris
# tris
# PGM 15.5989 10.0 True
# tris
# tris
# PGM 15.5989 10.0 True
# tris
# tris
# tris
# tris
# RPE 0.89 10.0 False
# tris
# tris
# RPE 0.89 10.0 False
# tris
# tris
# tris
# tris
# FRD2 0.0 10.0 False
# tris
# tris
# FRD2 0.0 10.0 False
# tris
# tris
# FRD2 0.0 10.0 False
# tris
# tris
# FRD2 0.0 10.0 False
# tris
# tris
# FRD2 0.0 10.0 False
# tris
# tris
# FRD2 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# NADPHQR3 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYC3Ptex 0.0 10.0 False
# tris
# tris
# GLYC3Ptex 0.0 10.0 False
# tris
# tris
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# PPS 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLBRAN2 0.0 10.0 False
# tris
# tris
# GLBRAN2 0.0 10.0 False
# tris
# tris
# tris
# tris
# G3PD7 0.0 10.0 False
# tris
# tris
# G3PD7 0.0 10.0 False
# tris
# tris
# G3PD7 0.0 10.0 False
# tris
# tris
# G3PD7 0.0 10.0 False
# tris
# tris
# G3PD7 0.0 10.0 False
# tris
# tris
# G3PD7 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# TMAOR2 0.0 10.0 False
# tris
# tris
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# FDH5pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# SPODM 0.00342 10.0 False
# tris
# tris
# SPODM 0.00342 10.0 False
# tris
# tris
# SPODM 0.00342 10.0 False
# tris
# tris
# SPODM 0.00342 10.0 False
# tris
# tris
# SPODM 0.00342 10.0 False
# tris
# tris
# SPODM 0.00342 10.0 False
# tris
# tris
# tris
# tris
# SUCCt2_2pp 0.0 10.0 False
# tris
# tris
# SUCCt2_2pp 0.0 10.0 False
# tris
# tris
# SUCCt2_2pp 0.0 10.0 False
# tris
# tris
# SUCCt2_2pp 0.0 10.0 False
# tris
# tris
# SUCCt2_2pp 0.0 10.0 False
# tris
# tris
# SUCCt2_2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# SUCCt2_3pp 0.0 10.0 False
# tris
# tris
# SUCCt2_3pp 0.0 10.0 False
# tris
# tris
# SUCCt2_3pp 0.0 10.0 False
# tris
# tris
# SUCCt2_3pp 0.0 10.0 False
# tris
# tris
# SUCCt2_3pp 0.0 10.0 False
# tris
# tris
# SUCCt2_3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# FBP 0.0 10.0 False
# tris
# tris
# FBP 0.0 10.0 False
# tris
# tris
# FBP 0.0 10.0 False
# tris
# tris
# FBP 0.0 10.0 False
# tris
# tris
# FBP 0.0 10.0 False
# tris
# tris
# FBP 0.0 10.0 False
# tris
# tris
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# HYD1pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# TPI 8.32823 10.0 False
# tris
# tris
# TPI 8.32823 10.0 False
# tris
# tris
# tris
# tris
# 12PPDRtex 0.0 10.0 False
# tris
# tris
# 12PPDRtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# ICL 0.0 10.0 False
# tris
# tris
# ICL 0.0 10.0 False
# tris
# tris
# ICL 0.0 10.0 False
# tris
# tris
# ICL 0.0 10.0 False
# tris
# tris
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# ICDHyr 6.913 10.0 False
# tris
# tris
# tris
# tris
# D_LACtex 0.0 10.0 False
# tris
# tris
# D_LACtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# MDH3 0.0 10.0 False
# tris
# tris
# MDH3 0.0 10.0 False
# tris
# tris
# MDH3 0.0 10.0 False
# tris
# tris
# MDH3 0.0 10.0 False
# tris
# tris
# MDH3 0.0 10.0 False
# tris
# tris
# MDH3 0.0 10.0 False
# tris
# tris
# tris
# tris
# FORtex 0.0 10.0 False
# tris
# tris
# FORtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# ENO 15.5989 10.0 True
# tris
# tris
# ENO 15.5989 10.0 True
# tris
# tris
# ENO 15.5989 10.0 True
# tris
# tris
# ENO 15.5989 10.0 True
# tris
# tris
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# tris
# tris
# G3PT 0.0 10.0 False
# tris
# tris
# G3PT 0.0 10.0 False
# tris
# tris
# G3PT 0.0 10.0 False
# tris
# tris
# G3PT 0.0 10.0 False
# tris
# tris
# G3PT 0.0 10.0 False
# tris
# tris
# G3PT 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# GLCDpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCt2pp 0.0 10.0 False
# tris
# tris
# GLCt2pp 0.0 10.0 False
# tris
# tris
# GLCt2pp 0.0 10.0 False
# tris
# tris
# GLCt2pp 0.0 10.0 False
# tris
# tris
# GLCt2pp 0.0 10.0 False
# tris
# tris
# GLCt2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# RBK 0.0 10.0 False
# tris
# tris
# tris
# tris
# PTAr 0.51058 10.0 False
# tris
# tris
# PTAr 0.51058 10.0 False
# tris
# tris
# PTAr 0.51058 10.0 False
# tris
# tris
# PTAr 0.51058 10.0 False
# tris
# tris
# PTAr 0.51058 10.0 False
# tris
# tris
# PTAr 0.51058 10.0 False
# tris
# tris
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# GAPD 17.10543 10.0 True
# tris
# tris
# tris
# tris
# CITt3pp 0.0 10.0 False
# tris
# tris
# CITt3pp 0.0 10.0 False
# tris
# tris
# CITt3pp 0.0 10.0 False
# tris
# tris
# CITt3pp 0.0 10.0 False
# tris
# tris
# CITt3pp 0.0 10.0 False
# tris
# tris
# CITt3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# SUCOAS 5.50968 10.0 False
# tris
# tris
# tris
# tris
# H2tex 0.0 10.0 False
# tris
# tris
# H2tex 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACONTa 6.913 10.0 False
# tris
# tris
# ACONTa 6.913 10.0 False
# tris
# tris
# ACONTa 6.913 10.0 False
# tris
# tris
# ACONTa 6.913 10.0 False
# tris
# tris
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# PFK 8.45176 10.0 False
# tris
# tris
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# LALDO2x 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACtex 0.0 10.0 False
# tris
# tris
# ACtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# ATPM 6.86 10.0 False
# tris
# tris
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# PFK_3 0.0 10.0 False
# tris
# tris
# tris
# tris
# MGSA 0.0 10.0 False
# tris
# tris
# MGSA 0.0 10.0 False
# tris
# tris
# MGSA 0.0 10.0 False
# tris
# tris
# MGSA 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# NADH9 0.0 10.0 False
# tris
# tris
# tris
# tris
# F6Pt6_2pp 0.0 10.0 False
# tris
# tris
# F6Pt6_2pp 0.0 10.0 False
# tris
# tris
# F6Pt6_2pp 0.0 10.0 False
# tris
# tris
# F6Pt6_2pp 0.0 10.0 False
# tris
# tris
# F6Pt6_2pp 0.0 10.0 False
# tris
# tris
# F6Pt6_2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# NTRIR2x 0.0 10.0 False
# tris
# tris
# tris
# tris
# CITt7pp 0.0 10.0 False
# tris
# tris
# CITt7pp 0.0 10.0 False
# tris
# tris
# CITt7pp 0.0 10.0 False
# tris
# tris
# CITt7pp 0.0 10.0 False
# tris
# tris
# CITt7pp 0.0 10.0 False
# tris
# tris
# CITt7pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# F6PA 0.0 10.0 False
# tris
# tris
# F6PA 0.0 10.0 False
# tris
# tris
# F6PA 0.0 10.0 False
# tris
# tris
# F6PA 0.0 10.0 False
# tris
# tris
# tris
# tris
# MDH2 0.0 10.0 False
# tris
# tris
# MDH2 0.0 10.0 False
# tris
# tris
# MDH2 0.0 10.0 False
# tris
# tris
# MDH2 0.0 10.0 False
# tris
# tris
# MDH2 0.0 10.0 False
# tris
# tris
# MDH2 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYC3Pt6pp 0.0 10.0 False
# tris
# tris
# GLYC3Pt6pp 0.0 10.0 False
# tris
# tris
# GLYC3Pt6pp 0.0 10.0 False
# tris
# tris
# GLYC3Pt6pp 0.0 10.0 False
# tris
# tris
# GLYC3Pt6pp 0.0 10.0 False
# tris
# tris
# GLYC3Pt6pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# PYRt2rpp 0.0 10.0 False
# tris
# tris
# PYRt2rpp 0.0 10.0 False
# tris
# tris
# PYRt2rpp 0.0 10.0 False
# tris
# tris
# PYRt2rpp 0.0 10.0 False
# tris
# tris
# PYRt2rpp 0.0 10.0 False
# tris
# tris
# PYRt2rpp 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLYCTO2 0.0 10.0 False
# tris
# tris
# GLYCTO2 0.0 10.0 False
# tris
# tris
# GLYCTO2 0.0 10.0 False
# tris
# tris
# GLYCTO2 0.0 10.0 False
# tris
# tris
# GLYCTO2 0.0 10.0 False
# tris
# tris
# GLYCTO2 0.0 10.0 False
# tris
# tris
# tris
# tris
# TKT1 0.61192 10.0 False
# tris
# tris
# TKT1 0.61192 10.0 False
# tris
# tris
# TKT1 0.61192 10.0 False
# tris
# tris
# TKT1 0.61192 10.0 False
# tris
# tris
# TKT1 0.61192 10.0 False
# tris
# tris
# TKT1 0.61192 10.0 False
# tris
# tris
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# THD2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# ALCD2x 0.0 10.0 False
# tris
# tris
# tris
# tris
# SUCCtex 0.0 10.0 False
# tris
# tris
# SUCCtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# DMSOR2 0.0 10.0 False
# tris
# tris
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# G3PD2 0.12193 10.0 False
# tris
# tris
# tris
# tris
# XYLI1 0.0 10.0 False
# tris
# tris
# XYLI1 0.0 10.0 False
# tris
# tris
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# NTRIR4pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# CITL 0.0 10.0 False
# tris
# tris
# CITL 0.0 10.0 False
# tris
# tris
# CITL 0.0 10.0 False
# tris
# tris
# CITL 0.0 10.0 False
# tris
# tris
# tris
# tris
# FORt2pp 0.0 10.0 False
# tris
# tris
# FORt2pp 0.0 10.0 False
# tris
# tris
# FORt2pp 0.0 10.0 False
# tris
# tris
# FORt2pp 0.0 10.0 False
# tris
# tris
# FORt2pp 0.0 10.0 False
# tris
# tris
# FORt2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCtex_copy1 10.0 10.0 False
# tris
# tris
# GLCtex_copy1 10.0 10.0 False
# tris
# tris
# tris
# tris
# PYRtex 0.0 10.0 False
# tris
# tris
# PYRtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# SUCDi 5.97256 10.0 False
# tris
# tris
# SUCDi 5.97256 10.0 False
# tris
# tris
# SUCDi 5.97256 10.0 False
# tris
# tris
# SUCDi 5.97256 10.0 False
# tris
# tris
# SUCDi 5.97256 10.0 False
# tris
# tris
# SUCDi 5.97256 10.0 False
# tris
# tris
# tris
# tris
# FORtppi 0.0 10.0 False
# tris
# tris
# FORtppi 0.0 10.0 False
# tris
# tris
# tris
# tris
# TALA 0.61192 10.0 False
# tris
# tris
# TALA 0.61192 10.0 False
# tris
# tris
# TALA 0.61192 10.0 False
# tris
# tris
# TALA 0.61192 10.0 False
# tris
# tris
# TALA 0.61192 10.0 False
# tris
# tris
# TALA 0.61192 10.0 False
# tris
# tris
# tris
# tris
# TKT2 0.27807 10.0 False
# tris
# tris
# TKT2 0.27807 10.0 False
# tris
# tris
# TKT2 0.27807 10.0 False
# tris
# tris
# TKT2 0.27807 10.0 False
# tris
# tris
# TKT2 0.27807 10.0 False
# tris
# tris
# TKT2 0.27807 10.0 False
# tris
# tris
# tris
# tris
# XYLtex 0.0 10.0 False
# tris
# tris
# XYLtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# AKGDH 5.97006 10.0 False
# tris
# tris
# tris
# tris
# AKGtex 0.0 10.0 False
# tris
# tris
# AKGtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# NO3R2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# LGTHL 0.0 10.0 False
# tris
# tris
# LGTHL 0.0 10.0 False
# tris
# tris
# LGTHL 0.0 10.0 False
# tris
# tris
# LGTHL 0.0 10.0 False
# tris
# tris
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# ALDD2y 0.0 10.0 False
# tris
# tris
# tris
# tris
# EDD 0.0 10.0 False
# tris
# tris
# EDD 0.0 10.0 False
# tris
# tris
# EDD 0.0 10.0 False
# tris
# tris
# EDD 0.0 10.0 False
# tris
# tris
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# FRUK 0.0 10.0 False
# tris
# tris
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# FDH4pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# MOX 0.0 10.0 False
# tris
# tris
# MOX 0.0 10.0 False
# tris
# tris
# MOX 0.0 10.0 False
# tris
# tris
# MOX 0.0 10.0 False
# tris
# tris
# MOX 0.0 10.0 False
# tris
# tris
# MOX 0.0 10.0 False
# tris
# tris
# tris
# tris
# CO2tpp 24.00329 10.0 True
# tris
# tris
# CO2tpp 24.00329 10.0 True
# tris
# tris
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# ME1 0.0 10.0 False
# tris
# tris
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# XYLK 0.0 10.0 False
# tris
# tris
# tris
# tris
# G6Pt6_2pp 0.0 10.0 False
# tris
# tris
# G6Pt6_2pp 0.0 10.0 False
# tris
# tris
# G6Pt6_2pp 0.0 10.0 False
# tris
# tris
# G6Pt6_2pp 0.0 10.0 False
# tris
# tris
# G6Pt6_2pp 0.0 10.0 False
# tris
# tris
# G6Pt6_2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# NADTRHD 0.0 10.0 False
# tris
# tris
# NADTRHD 0.0 10.0 False
# tris
# tris
# NADTRHD 0.0 10.0 False
# tris
# tris
# NADTRHD 0.0 10.0 False
# tris
# tris
# NADTRHD 0.0 10.0 False
# tris
# tris
# NADTRHD 0.0 10.0 False
# tris
# tris
# tris
# tris
# G3PD6 0.0 10.0 False
# tris
# tris
# G3PD6 0.0 10.0 False
# tris
# tris
# G3PD6 0.0 10.0 False
# tris
# tris
# G3PD6 0.0 10.0 False
# tris
# tris
# G3PD6 0.0 10.0 False
# tris
# tris
# G3PD6 0.0 10.0 False
# tris
# tris
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# GND 2.35537 10.0 False
# tris
# tris
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# HEX1 0.0 10.0 False
# tris
# tris
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# DMSOR1 0.0 10.0 False
# tris
# tris
# tris
# tris
# FUMt2_3pp 0.0 10.0 False
# tris
# tris
# FUMt2_3pp 0.0 10.0 False
# tris
# tris
# FUMt2_3pp 0.0 10.0 False
# tris
# tris
# FUMt2_3pp 0.0 10.0 False
# tris
# tris
# FUMt2_3pp 0.0 10.0 False
# tris
# tris
# FUMt2_3pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# TMAOR1 0.0 10.0 False
# tris
# tris
# tris
# tris
# FBA 8.45176 10.0 False
# tris
# tris
# FBA 8.45176 10.0 False
# tris
# tris
# FBA 8.45176 10.0 False
# tris
# tris
# FBA 8.45176 10.0 False
# tris
# tris
# tris
# tris
# G6PP 0.0 10.0 False
# tris
# tris
# G6PP 0.0 10.0 False
# tris
# tris
# G6PP 0.0 10.0 False
# tris
# tris
# G6PP 0.0 10.0 False
# tris
# tris
# G6PP 0.0 10.0 False
# tris
# tris
# G6PP 0.0 10.0 False
# tris
# tris
# tris
# tris
# RIBtex 0.0 10.0 False
# tris
# tris
# RIBtex 0.0 10.0 False
# tris
# tris
# tris
# tris
# FRUpts2pp 0.0 10.0 False
# tris
# tris
# FRUpts2pp 0.0 10.0 False
# tris
# tris
# FRUpts2pp 0.0 10.0 False
# tris
# tris
# FRUpts2pp 0.0 10.0 False
# tris
# tris
# FRUpts2pp 0.0 10.0 False
# tris
# tris
# FRUpts2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# ACALD 0.0 10.0 False
# tris
# tris
# tris
# tris
# HCO3E 0.46097 10.0 False
# tris
# tris
# HCO3E 0.46097 10.0 False
# tris
# tris
# HCO3E 0.46097 10.0 False
# tris
# tris
# HCO3E 0.46097 10.0 False
# tris
# tris
# HCO3E 0.46097 10.0 False
# tris
# tris
# HCO3E 0.46097 10.0 False
# tris
# tris
# tris
# tris
# FHL 0.0 10.0 False
# tris
# tris
# FHL 0.0 10.0 False
# tris
# tris
# FHL 0.0 10.0 False
# tris
# tris
# FHL 0.0 10.0 False
# tris
# tris
# FHL 0.0 10.0 False
# tris
# tris
# FHL 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCS1 0.0 10.0 False
# tris
# tris
# GLCS1 0.0 10.0 False
# tris
# tris
# GLCS1 0.0 10.0 False
# tris
# tris
# GLCS1 0.0 10.0 False
# tris
# tris
# GLCS1 0.0 10.0 False
# tris
# tris
# tris
# tris
# G6Ptex 0.0 10.0 False
# tris
# tris
# G6Ptex 0.0 10.0 False
# tris
# tris
# tris
# tris
# OAADC 0.0 10.0 False
# tris
# tris
# OAADC 0.0 10.0 False
# tris
# tris
# OAADC 0.0 10.0 False
# tris
# tris
# OAADC 0.0 10.0 False
# tris
# tris
# OAADC 0.0 10.0 False
# tris
# tris
# OAADC 0.0 10.0 False
# tris
# tris
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# DMSOR2pp 0.0 10.0 False
# tris
# tris
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# LDH_D2 0.0 10.0 False
# tris
# tris
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# L_LACD2 0.0 10.0 False
# tris
# tris
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# GLCptspp 10.0 10.0 False
# tris
# tris
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# tris
# L_LACD3 0.0 10.0 False
# tris
# None nodes divi
# tris
# mal__L_c n2075291 mal__L_c
# tris
#
# nad_c n2075292 nad_c
# tris
#
# nadh_c n2075293 nadh_c
# tris
#
# h_c n2075294 h_c
# tris
#
# oaa_c n2075295 oaa_c
# tris
#
# q8h2_c n2075296 q8h2_c
# tris
#
# no2_p n2075297 no2_p
# tris
#
# h_p n2075298 h_p
# tris
#
# h2o_p n2075299 h2o_p
# tris
#
# q8_c n2075300 q8_c
# tris
#
# nh4_p n2075301 nh4_p
# tris
#
# 2dmmq8_c n2075302 2dmmq8_c
# tris
#
# h_c n2075303 h_c
# tris
#
# nadph_c n2075304 nadph_c
# tris
#
# 2dmmql8_c n2075305 2dmmql8_c
# tris
#
# nadp_c n2075306 nadp_c
# tris
#
# nadh_c n2075307 nadh_c
# tris
#
# h_c n2075308 h_c
# tris
#
# mqn8_c n2075309 mqn8_c
# tris
#
# nad_c n2075310 nad_c
# tris
#
# h_p n2075311 h_p
# tris
#
# mql8_c n2075312 mql8_c
# tris
#
# h_p n2075313 h_p
# tris
#
# h_c n2075314 h_c
# tris
#
# mal__L_p n2075315 mal__L_p
# tris
#
# lac__D_p n2075316 lac__D_p
# tris
#
# h_p n2075317 h_p
# tris
#
# lac__D_c n2075318 lac__D_c
# tris
#
# h_c n2075319 h_c
# tris
#
# g1p_p n2075320 g1p_p
# tris
#
# h2o_p n2075321 h2o_p
# tris
#
# pi_p n2075322 pi_p
# tris
#
# glc__D_p n2075323 glc__D_p
# tris
#
# acon_T_c n2075324 acon_T_c
# tris
#
# amet_c n2075325 amet_c
# tris
#
# ahcys_c n2075326 ahcys_c
# tris
#
# aconm_c n2075327 aconm_c
# tris
#
# acald_e n2075328 acald_e
# tris
#
# acald_p n2075329 acald_p
# tris
#
# glyclt_c n2075331 glyclt_c
# tris
#
# glx_c n2075332 glx_c
# tris
#
# acon_C_c n2075333 acon_C_c
# tris
#
# h_c n2075334 h_c
# tris
#
# o2_c n2075335 o2_c
# tris
#
# h2o_c n2075336 h2o_c
# tris
#
# h_p n2075337 h_p
# tris
#
# pep_c n2075338 pep_c
# tris
#
# h2o_c n2075339 h2o_c
# tris
#
# co2_c n2075340 co2_c
# tris
#
# h_c n2075341 h_c
# tris
#
# pi_c n2075342 pi_c
# tris
#
# f6p_e n2075343 f6p_e
# tris
#
# f6p_p n2075344 f6p_p
# tris
#
# h2o_c n2075345 h2o_c
# tris
#
# accoa_c n2075346 accoa_c
# tris
#
# glx_c n2075347 glx_c
# tris
#
# h_c n2075348 h_c
# tris
#
# coa_c n2075349 coa_c
# tris
#
# h2_c n2075350 h2_c
# tris
#
# h_c n2075351 h_c
# tris
#
# h_p n2075352 h_p
# tris
#
# s17bp_c n2075353 s17bp_c
# tris
#
# e4p_c n2075354 e4p_c
# tris
#
# dhap_c n2075355 dhap_c
# tris
#
# etoh_p n2075356 etoh_p
# tris
#
# etoh_c n2075357 etoh_c
# tris
#
# h_c n2075358 h_c
# tris
#
# o2_c n2075359 o2_c
# tris
#
# h2o_c n2075360 h2o_c
# tris
#
# h_p n2075361 h_p
# tris
#
# h_p n2075362 h_p
# tris
#
# fum_p n2075363 fum_p
# tris
#
# h_c n2075364 h_c
# tris
#
# fum_c n2075365 fum_c
# tris
#
# pi_c n2075366 pi_c
# tris
#
# glycogen_c n2075367 glycogen_c
# tris
#
# g1p_c n2075368 g1p_c
# tris
#
# no3_p n2075369 no3_p
# tris
#
# no2_p n2075370 no2_p
# tris
#
# h2o_p n2075371 h2o_p
# tris
#
# h_c n2075372 h_c
# tris
#
# nadh_c n2075373 nadh_c
# tris
#
# h_p n2075374 h_p
# tris
#
# nad_c n2075375 nad_c
# tris
#
# dsbard_p n2075376 dsbard_p
# tris
#
# dsbaox_p n2075377 dsbaox_p
# tris
#
# tmao_p n2075378 tmao_p
# tris
#
# h_p n2075379 h_p
# tris
#
# h2o_p n2075380 h2o_p
# tris
#
# tma_p n2075381 tma_p
# tris
#
# accoa_c n2075382 accoa_c
# tris
#
# h2o_c n2075383 h2o_c
# tris
#
# cit_c n2075384 cit_c
# tris
#
# h_c n2075385 h_c
# tris
#
# coa_c n2075386 coa_c
# tris
#
# atp_c n2075387 atp_c
# tris
#
# h_c n2075388 h_c
# tris
#
# ppi_c n2075389 ppi_c
# tris
#
# adpglc_c n2075390 adpglc_c
# tris
#
# glyc_c n2075391 glyc_c
# tris
#
# glyc_p n2075392 glyc_p
# tris
#
# glyclt_c n2075393 glyclt_c
# tris
#
# glx_c n2075394 glx_c
# tris
#
# g6p_c n2075395 g6p_c
# tris
#
# f6p_c n2075396 f6p_c
# tris
#
# glyc_e n2075397 glyc_e
# tris
#
# o2_c n2075398 o2_c
# tris
#
# h_c n2075399 h_c
# tris
#
# o2s_c n2075400 o2s_c
# tris
#
# h2o_c n2075401 h2o_c
# tris
#
# lgt__S_c n2075402 lgt__S_c
# tris
#
# h_c n2075403 h_c
# tris
#
# gthrd_c n2075404 gthrd_c
# tris
#
# atp_c n2075405 atp_c
# tris
#
# 3pg_c n2075406 3pg_c
# tris
#
# adp_c n2075407 adp_c
# tris
#
# 13dpg_c n2075408 13dpg_c
# tris
#
# fum_e n2075409 fum_e
# tris
#
# h2o2_c n2075410 h2o2_c
# tris
#
# h2o_c n2075411 h2o_c
# tris
#
# o2_c n2075412 o2_c
# tris
#
# etoh_e n2075413 etoh_e
# tris
#
# h2_p n2075416 h2_p
# tris
#
# h2_c n2075417 h2_c
# tris
#
# h_p n2075418 h_p
# tris
#
# o2s_p n2075419 o2s_p
# tris
#
# h2o2_p n2075420 h2o2_p
# tris
#
# o2_p n2075421 o2_p
# tris
#
# glyc3p_c n2075422 glyc3p_c
# tris
#
# dhap_c n2075423 dhap_c
# tris
#
# nadp_c n2075424 nadp_c
# tris
#
# nadph_c n2075425 nadph_c
# tris
#
# 6pgl_c n2075426 6pgl_c
# tris
#
# h_c n2075427 h_c
# tris
#
# ac_c n2075428 ac_c
# tris
#
# atp_c n2075429 atp_c
# tris
#
# coa_c n2075430 coa_c
# tris
#
# amp_c n2075431 amp_c
# tris
#
# ppi_c n2075432 ppi_c
# tris
#
# atp_c n2075433 atp_c
# tris
#
# h_c n2075434 h_c
# tris
#
# glyc3p_c n2075435 glyc3p_c
# tris
#
# adp_c n2075436 adp_c
# tris
#
# h_p n2075437 h_p
# tris
#
# akg_p n2075438 akg_p
# tris
#
# h_c n2075439 h_c
# tris
#
# akg_c n2075440 akg_c
# tris
#
# h_p n2075441 h_p
# tris
#
# h_c n2075442 h_c
# tris
#
# h2o_c n2075443 h2o_c
# tris
#
# 6pgc_c n2075444 6pgc_c
# tris
#
# h_c n2075445 h_c
# tris
#
# 12ppd__R_p n2075446 12ppd__R_p
# tris
#
# 12ppd__R_c n2075447 12ppd__R_c
# tris
#
# dmso_p n2075448 dmso_p
# tris
#
# dmso_c n2075449 dmso_c
# tris
#
# h_p n2075450 h_p
# tris
#
# adp_c n2075451 adp_c
# tris
#
# pi_c n2075452 pi_c
# tris
#
# h_c n2075453 h_c
# tris
#
# atp_c n2075454 atp_c
# tris
#
# h2o_c n2075455 h2o_c
# tris
#
# nadh_c n2075456 nadh_c
# tris
#
# h_c n2075457 h_c
# tris
#
# nad_c n2075458 nad_c
# tris
#
# h_p n2075459 h_p
# tris
#
# atp_c n2075460 atp_c
# tris
#
# adp_c n2075461 adp_c
# tris
#
# actp_c n2075462 actp_c
# tris
#
# bglycogen_c n2075463 bglycogen_c
# tris
#
# r5p_c n2075464 r5p_c
# tris
#
# ru5p__D_c n2075465 ru5p__D_c
# tris
#
# h_p n2075466 h_p
# tris
#
# xyl__D_p n2075467 xyl__D_p
# tris
#
# xyl__D_c n2075468 xyl__D_c
# tris
#
# h_c n2075469 h_c
# tris
#
# g1p_e n2075470 g1p_e
# tris
#
# mal__L_e n2075471 mal__L_e
# tris
#
# o2_c n2075472 o2_c
# tris
#
# h_c n2075473 h_c
# tris
#
# h2o_c n2075474 h2o_c
# tris
#
# h_p n2075475 h_p
# tris
#
# dmso_p n2075476 dmso_p
# tris
#
# h2o_p n2075477 h2o_p
# tris
#
# dms_p n2075478 dms_p
# tris
#
# pep_c n2075479 pep_c
# tris
#
# fru_p n2075480 fru_p
# tris
#
# f1p_c n2075481 f1p_c
# tris
#
# pyr_c n2075482 pyr_c
# tris
#
# atp_c n2075483 atp_c
# tris
#
# ppi_c n2075484 ppi_c
# tris
#
# pppi_c n2075485 pppi_c
# tris
#
# adp_c n2075486 adp_c
# tris
#
# lac__L_c n2075487 lac__L_c
# tris
#
# q8_c n2075488 q8_c
# tris
#
# q8h2_c n2075489 q8h2_c
# tris
#
# adp_c n2075491 adp_c
# tris
#
# h_c n2075492 h_c
# tris
#
# atp_c n2075493 atp_c
# tris
#
# o2_c n2075496 o2_c
# tris
#
# o2s_c n2075497 o2s_c
# tris
#
# h_c n2075498 h_c
# tris
#
# h_p n2075499 h_p
# tris
#
# lac__L_p n2075500 lac__L_p
# tris
#
# h_c n2075501 h_c
# tris
#
# nadh_c n2075502 nadh_c
# tris
#
# h_c n2075503 h_c
# tris
#
# nad_c n2075504 nad_c
# tris
#
# nad_c n2075505 nad_c
# tris
#
# dha_c n2075506 dha_c
# tris
#
# nadh_c n2075507 nadh_c
# tris
#
# h_c n2075508 h_c
# tris
#
# h_p n2075509 h_p
# tris
#
# h_c n2075510 h_c
# tris
#
# pep_c n2075511 pep_c
# tris
#
# pyr_c n2075512 pyr_c
# tris
#
# co2_e n2075513 co2_e
# tris
#
# co2_p n2075514 co2_p
# tris
#
# no3_p n2075515 no3_p
# tris
#
# h2o_p n2075516 h2o_p
# tris
#
# no2_p n2075517 no2_p
# tris
#
# dsbard_p n2075518 dsbard_p
# tris
#
# dsbaox_p n2075519 dsbaox_p
# tris
#
# h2o_c n2075520 h2o_c
# tris
#
# glyc3p_p n2075521 glyc3p_p
# tris
#
# atp_c n2075522 atp_c
# tris
#
# h_c n2075523 h_c
# tris
#
# pi_c n2075524 pi_c
# tris
#
# adp_c n2075525 adp_c
# tris
#
# atp_c n2075526 atp_c
# tris
#
# co2_c n2075527 co2_c
# tris
#
# adp_c n2075528 adp_c
# tris
#
# lac__L_e n2075529 lac__L_e
# tris
#
# nad_c n2075530 nad_c
# tris
#
# coa_c n2075531 coa_c
# tris
#
# nadh_c n2075532 nadh_c
# tris
#
# co2_c n2075533 co2_c
# tris
#
# nadp_c n2075534 nadp_c
# tris
#
# co2_c n2075535 co2_c
# tris
#
# nadph_c n2075536 nadph_c
# tris
#
# acald_c n2075537 acald_c
# tris
#
# fru_e n2075538 fru_e
# tris
#
# h2o_c n2075539 h2o_c
# tris
#
# atp_c n2075540 atp_c
# tris
#
# adp_c n2075541 adp_c
# tris
#
# pi_c n2075542 pi_c
# tris
#
# h_c n2075543 h_c
# tris
#
# 2dmmql8_c n2075544 2dmmql8_c
# tris
#
# succ_c n2075545 succ_c
# tris
#
# 2dmmq8_c n2075546 2dmmq8_c
# tris
#
# h2o_c n2075547 h2o_c
# tris
#
# h_c n2075548 h_c
# tris
#
# pi_c n2075549 pi_c
# tris
#
# h_p n2075550 h_p
# tris
#
# ac_p n2075551 ac_p
# tris
#
# h_c n2075552 h_c
# tris
#
# h2_c n2075553 h2_c
# tris
#
# h_c n2075554 h_c
# tris
#
# h_p n2075555 h_p
# tris
#
# pyr_c n2075556 pyr_c
# tris
#
# h2o_c n2075557 h2o_c
# tris
#
# co2_c n2075558 co2_c
# tris
#
# ac_c n2075559 ac_c
# tris
#
# nadph_c n2075560 nadph_c
# tris
#
# h_c n2075561 h_c
# tris
#
# nadp_c n2075562 nadp_c
# tris
#
# h2o_c n2075563 h2o_c
# tris
#
# icit_c n2075564 icit_c
# tris
#
# cit_e n2075565 cit_e
# tris
#
# cit_p n2075566 cit_p
# tris
#
# rib__D_p n2075567 rib__D_p
# tris
#
# h2o_c n2075568 h2o_c
# tris
#
# atp_c n2075569 atp_c
# tris
#
# pi_c n2075570 pi_c
# tris
#
# adp_c n2075571 adp_c
# tris
#
# rib__D_c n2075572 rib__D_c
# tris
#
# h_c n2075573 h_c
# tris
#
# h2o_c n2075574 h2o_c
# tris
#
# 2ddg6p_c n2075575 2ddg6p_c
# tris
#
# g3p_c n2075576 g3p_c
# tris
#
# coa_c n2075577 coa_c
# tris
#
# for_c n2075578 for_c
# tris
#
# h2o_c n2075579 h2o_c
# tris
#
# h_c n2075580 h_c
# tris
#
# pi_c n2075581 pi_c
# tris
#
# no3_c n2075582 no3_c
# tris
#
# h_c n2075583 h_c
# tris
#
# h_p n2075584 h_p
# tris
#
# no2_c n2075585 no2_c
# tris
#
# h2o_c n2075586 h2o_c
# tris
#
# pi_c n2075587 pi_c
# tris
#
# h_p n2075588 h_p
# tris
#
# tmao_p n2075589 tmao_p
# tris
#
# tma_p n2075590 tma_p
# tris
#
# h2o_p n2075591 h2o_p
# tris
#
# nadh_c n2075592 nadh_c
# tris
#
# h_c n2075593 h_c
# tris
#
# nad_c n2075594 nad_c
# tris
#
# nad_c n2075595 nad_c
# tris
#
# h_c n2075596 h_c
# tris
#
# nadh_c n2075597 nadh_c
# tris
#
# h_c n2075598 h_c
# tris
#
# nadh_c n2075599 nadh_c
# tris
#
# lald__D_c n2075600 lald__D_c
# tris
#
# nad_c n2075601 nad_c
# tris
#
# 2pg_c n2075602 2pg_c
# tris
#
# xu5p__D_c n2075603 xu5p__D_c
# tris
#
# mql8_c n2075604 mql8_c
# tris
#
# mqn8_c n2075605 mqn8_c
# tris
#
# nadph_c n2075606 nadph_c
# tris
#
# h_c n2075607 h_c
# tris
#
# nadp_c n2075608 nadp_c
# tris
#
# glyc3p_e n2075609 glyc3p_e
# tris
#
# atp_c n2075610 atp_c
# tris
#
# h2o_c n2075611 h2o_c
# tris
#
# amp_c n2075612 amp_c
# tris
#
# pi_c n2075613 pi_c
# tris
#
# h_c n2075614 h_c
# tris
#
# glyc3p_c n2075615 glyc3p_c
# tris
#
# dhap_c n2075616 dhap_c
# tris
#
# pep_c n2075617 pep_c
# tris
#
# pyr_c n2075618 pyr_c
# tris
#
# tmao_c n2075619 tmao_c
# tris
#
# h_c n2075620 h_c
# tris
#
# h2o_c n2075621 h2o_c
# tris
#
# tma_c n2075622 tma_c
# tris
#
# for_p n2075623 for_p
# tris
#
# h_c n2075624 h_c
# tris
#
# co2_p n2075625 co2_p
# tris
#
# h_p n2075626 h_p
# tris
#
# o2s_c n2075629 o2s_c
# tris
#
# h_c n2075630 h_c
# tris
#
# h2o2_c n2075631 h2o2_c
# tris
#
# o2_c n2075632 o2_c
# tris
#
# succ_p n2075633 succ_p
# tris
#
# ...
# tris
#
# ac_c n2075754 ac_c
# tris
#
# h_p n2075755 h_p
# tris
#
# h_c n2075756 h_c
# tris
#
# glc__D_e n2075757 glc__D_e
# tris
#
# pyr_e n2075758 pyr_e
# tris
#
# q8_c n2075759 q8_c
# tris
#
# q8h2_c n2075760 q8h2_c
# tris
#
# xyl__D_e n2075761 xyl__D_e
# tris
#
# nad_c n2075762 nad_c
# tris
#
# coa_c n2075763 coa_c
# tris
#
# nadh_c n2075764 nadh_c
# tris
#
# co2_c n2075765 co2_c
# tris
#
# akg_e n2075766 akg_e
# tris
#
# h_c n2075767 h_c
# tris
#
# no3_c n2075768 no3_c
# tris
#
# h_p n2075769 h_p
# tris
#
# no2_c n2075770 no2_c
# tris
#
# h2o_c n2075771 h2o_c
# tris
#
# nadp_c n2075772 nadp_c
# tris
#
# h2o_c n2075773 h2o_c
# tris
#
# nadph_c n2075774 nadph_c
# tris
#
# h_c n2075775 h_c
# tris
#
# h2o_c n2075776 h2o_c
# tris
#
# atp_c n2075777 atp_c
# tris
#
# h_c n2075778 h_c
# tris
#
# adp_c n2075779 adp_c
# tris
#
# h_c n2075780 h_c
# tris
#
# for_p n2075781 for_p
# tris
#
# co2_p n2075782 co2_p
# tris
#
# h_p n2075783 h_p
# tris
#
# o2_c n2075784 o2_c
# tris
#
# h2o2_c n2075785 h2o2_c
# tris
#
# co2_c n2075786 co2_c
# tris
#
# nad_c n2075787 nad_c
# tris
#
# nadh_c n2075788 nadh_c
# tris
#
# co2_c n2075789 co2_c
# tris
#
# atp_c n2075790 atp_c
# tris
#
# h_c n2075791 h_c
# tris
#
# adp_c n2075792 adp_c
# tris
#
# pi_c n2075793 pi_c
# tris
#
# g6p_p n2075794 g6p_p
# tris
#
# pi_p n2075795 pi_p
# tris
#
# glyc3p_c n2075796 glyc3p_c
# tris
#
# dhap_c n2075797 dhap_c
# tris
#
# nadp_c n2075798 nadp_c
# tris
#
# nadph_c n2075799 nadph_c
# tris
#
# co2_c n2075800 co2_c
# tris
#
# atp_c n2075801 atp_c
# tris
#
# adp_c n2075802 adp_c
# tris
#
# h_c n2075803 h_c
# tris
#
# dmso_c n2075804 dmso_c
# tris
#
# dms_c n2075805 dms_c
# tris
#
# h2o_c n2075806 h2o_c
# tris
#
# h_p n2075807 h_p
# tris
#
# h_c n2075808 h_c
# tris
#
# tmao_c n2075813 tmao_c
# tris
#
# h_c n2075814 h_c
# tris
#
# h2o_c n2075815 h2o_c
# tris
#
# tma_c n2075816 tma_c
# tris
#
# h2o_c n2075817 h2o_c
# tris
#
# pi_c n2075818 pi_c
# tris
#
# rib__D_e n2075819 rib__D_e
# tris
#
# pep_c n2075820 pep_c
# tris
#
# pyr_c n2075821 pyr_c
# tris
#
# nad_c n2075822 nad_c
# tris
#
# coa_c n2075823 coa_c
# tris
#
# h_c n2075824 h_c
# tris
#
# nadh_c n2075825 nadh_c
# tris
#
# co2_c n2075826 co2_c
# tris
#
# h2o_c n2075827 h2o_c
# tris
#
# h_c n2075828 h_c
# tris
#
# hco3_c n2075829 hco3_c
# tris
#
# h_c n2075830 h_c
# tris
#
# co2_c n2075831 co2_c
# tris
#
# h_c n2075832 h_c
# tris
#
# adp_c n2075833 adp_c
# tris
#
# g6p_e n2075834 g6p_e
# tris
#
# h_c n2075835 h_c
# tris
#
# co2_c n2075836 co2_c
# tris
#
# h2o_p n2075837 h2o_p
# tris
#
# dms_p n2075838 dms_p
# tris
#
# dms_p n2076047 dms_p
# tris
# dms_p n2076048 dms_p
# tris
# dms_p n2076049 dms_p
# tris
# dms_p n2076050 dms_p
# tris
# dms_p n2076051 dms_p
# tris
# dms_p n2076052 dms_p
# tris
# dms_p n2076053 dms_p
# tris
# dms_p n2076054 dms_p
# tris
# dms_p n2076055 dms_p
# tris
# dms_p n2076056 dms_p
# tris
# dms_p n2076057 dms_p
# tris
# dms_p n2076058 dms_p
# tris
# dms_p n2076059 dms_p
# tris
# dms_p n2076060 dms_p
# tris
# dms_p n2076061 dms_p
# tris
# dms_p n2076062 dms_p
# tris
# dms_p n2076063 dms_p
# tris
# dms_p n2076064 dms_p
# tris
# dms_p n2076065 dms_p
# tris
# dms_p n2076066 dms_p
# tris
# dms_p n2076067 dms_p
# tris
# dms_p n2076068 dms_p
# tris
# dms_p n2076069 dms_p
# tris
# dms_p n2076070 dms_p
# tris
# dms_p n2076071 dms_p
# tris
# dms_p n2076072 dms_p
# tris
# dms_p n2076073 dms_p
# tris
# dms_p n2076074 dms_p
# tris
# dms_p n2076075 dms_p
# tris
# dms_p n2076076 dms_p
# tris
# dms_p n2076077 dms_p
# tris
# dms_p n2076078 dms_p
# tris
# dms_p n2076079 dms_p
# tris
# dms_p n2076080 dms_p
# tris
# dms_p n2076081 dms_p
# tris
# dms_p n2076082 dms_p
# tris
# dms_p n2076083 dms_p
# tris
# dms_p n2076084 dms_p
# tris
# dms_p n2076085 dms_p
# tris
# dms_p n2076086 dms_p
# tris
# dms_p n2076087 dms_p
# tris
# dms_p n2076088 dms_p
# tris
# dms_p n2076089 dms_p
# tris
# dms_p n2076090 dms_p
# tris
# dms_p n2076091 dms_p
# tris
# dms_p n2076092 dms_p
# tris
# dms_p n2076093 dms_p
# tris
# dms_p n2076094 dms_p
# tris
# dms_p n2076095 dms_p
# tris
# dms_p n2076096 dms_p
# tris
# dms_p n2076097 dms_p
# tris
# dms_p n2076098 dms_p
# tris
# dms_p n2076099 dms_p
# tris
# dms_p n2076100 dms_p
# tris
# dms_p n2076101 dms_p
# tris
# dms_p n2076102 dms_p
# tris
# dms_p n2076103 dms_p
# tris
# dms_p n2076104 dms_p
# tris
# dms_p n2076105 dms_p
# tris
# dms_p n2076106 dms_p
# tris
# dms_p n2076107 dms_p
# tris
# dms_p n2076108 dms_p
# tris
# dms_p n2076109 dms_p
# tris
# dms_p n2076110 dms_p
# tris
# dms_p n2076111 dms_p
# tris
# dms_p n2076112 dms_p
# tris
# dms_p n2076113 dms_p
# tris
# dms_p n2076114 dms_p
# tris
# dms_p n2076115 dms_p
# tris
# dms_p n2076116 dms_p
# tris
# dms_p n2076117 dms_p
# tris
# dms_p n2076118 dms_p
# tris
# dms_p n2076119 dms_p
# tris
# dms_p n2076120 dms_p
# tris
# dms_p n2076121 dms_p
# tris
# dms_p n2076122 dms_p
# tris
# dms_p n2076123 dms_p
# tris
# dms_p n2076124 dms_p
# tris
# dms_p n2076125 dms_p
# tris
# dms_p n2076126 dms_p
# tris
# dms_p n2076127 dms_p
# tris
# dms_p n2076128 dms_p
# tris
# dms_p n2076129 dms_p
# tris
# dms_p n2076130 dms_p
# tris
# dms_p n2076131 dms_p
# tris
# dms_p n2076132 dms_p
# tris
# dms_p n2076133 dms_p
# tris
# dms_p n2076134 dms_p
# tris
# dms_p n2076135 dms_p
# tris
# dms_p n2076136 dms_p
# tris
# dms_p n2076137 dms_p
# tris
# dms_p n2076138 dms_p
# tris
# dms_p n2076139 dms_p
# tris
# dms_p n2076140 dms_p
# tris
# dms_p n2076141 dms_p
# tris
# dms_p n2076142 dms_p
# tris
# dms_p n2076143 dms_p
# tris
# dms_p n2076144 dms_p
# tris
# dms_p n2076145 dms_p
# tris
# dms_p n2076146 dms_p
# tris
# dms_p n2076147 dms_p
# tris
# dms_p n2076148 dms_p
# tris
# dms_p n2076149 dms_p
# tris
# dms_p n2076150 dms_p
# tris
# dms_p n2076151 dms_p
# tris
# dms_p n2076152 dms_p
# tris
# dms_p n2076153 dms_p
# tris
# dms_p n2076154 dms_p
# tris
# dms_p n2076155 dms_p
# tris
# dms_p n2076156 dms_p
# tris
# dms_p n2076157 dms_p
# tris
# dms_p n2076158 dms_p
# tris
# dms_p n2076159 dms_p
# tris
# dms_p n2076160 dms_p
# tris
# dms_p n2076161 dms_p
# tris
# dms_p n2076162 dms_p
# tris
# dms_p n2076163 dms_p
# tris
# dms_p n2076164 dms_p
# tris
# dms_p n2076165 dms_p
# tris
# dms_p n2076166 dms_p
# tris
# dms_p n2076167 dms_p
# tris
# dms_p n2076168 dms_p
# tris
# dms_p n2076169 dms_p
# tris
# dms_p n2076170 dms_p
# tris
# dms_p n2076171 dms_p
# tris
# dms_p n2076172 dms_p
# tris
# dms_p n2076173 dms_p
# tris
# dms_p n2076174 dms_p
# tris
# dms_p n2076175 dms_p
# tris
# dms_p n2076176 dms_p
# tris
# dms_p n2076177 dms_p
# tris
# dms_p n2076178 dms_p
# tris
# dms_p n2076179 dms_p
# tris
# dms_p n2076180 dms_p
# tris
# dms_p n2076181 dms_p
# tris
# dms_p n2076182 dms_p
# tris
# dms_p n2076183 dms_p
# tris
# dms_p n2076184 dms_p
# tris
# dms_p n2076185 dms_p
# tris
# dms_p n2076186 dms_p
# tris
# dms_p n2076187 dms_p
# tris
# dms_p n2076188 dms_p
# tris
# dms_p n2076189 dms_p
# tris
# dms_p n2076190 dms_p
# tris
# dms_p n2076191 dms_p
# tris
# dms_p n2076192 dms_p
# tris
# dms_p n2076193 dms_p
# tris
# dms_p n2076194 dms_p
# tris
# dms_p n2076195 dms_p
# tris
# dms_p n2076196 dms_p
# tris
# dms_p n2076197 dms_p
# tris
# dms_p n2076198 dms_p
# tris
# dms_p n2076202 dms_p
# tris
# dms_p n2076203 dms_p
# tris
# dms_p n2076204 dms_p
# tris
# dms_p n2076205 dms_p
# tris
# dms_p n2076206 dms_p
# tris
# dms_p n2076207 dms_p
# tris
# dms_p n2076208 dms_p
# tris
# dms_p n2076209 dms_p
# tris
# dms_p n2076210 dms_p
# tris
# dms_p n2076211 dms_p
# tris
# dms_p n2076212 dms_p
# tris
# dms_p n2076213 dms_p
# tris
# dms_p n2076214 dms_p
# tris
# dms_p n2076215 dms_p
# tris
# dms_p n2076216 dms_p
# tris
# dms_p n2076217 dms_p
# tris
# dms_p n2076218 dms_p
# tris
# dms_p n2076219 dms_p
# tris
# dms_p n2076220 dms_p
# tris
# dms_p n2076221 dms_p
# tris
# dms_p n2076222 dms_p
# tris
# dms_p n2076223 dms_p
# tris
# dms_p n2076224 dms_p
# tris
# dms_p n2076225 dms_p
# tris
# dms_p n2076226 dms_p
# tris
# dms_p n2076227 dms_p
# tris
# dms_p n2076228 dms_p
# tris
# dms_p n2076229 dms_p
# tris
# dms_p n2076230 dms_p
# tris
# dms_p n2076231 dms_p
# tris
# dms_p n2076232 dms_p
# tris
# dms_p n2076233 dms_p
# tris
# dms_p n2076234 dms_p
# tris
# dms_p n2076235 dms_p
# tris
# dms_p n2076236 dms_p
# tris
# dms_p n2076237 dms_p
# tris
# dms_p n2076238 dms_p
# tris
# dms_p n2076239 dms_p
# tris
# dms_p n2076240 dms_p
# tris
# dms_p n2076241 dms_p
# tris
# dms_p n2076242 dms_p
# tris
# dms_p n2076243 dms_p
# tris
# dms_p n2076244 dms_p
# tris
# dms_p n2076245 dms_p
# tris
# dms_p n2076246 dms_p
# tris
# dms_p n2076247 dms_p
# tris
# dms_p n2076248 dms_p
# tris
# dms_p n2076249 dms_p
# tris
# dms_p n2076250 dms_p
# tris
# dms_p n2076251 dms_p
# tris
# dms_p n2076252 dms_p
# tris
# dms_p n2076253 dms_p
# tris
# dms_p n2076254 dms_p
# tris
# dms_p n2076255 dms_p
# tris
# dms_p n2076256 dms_p
# tris
# dms_p n2076257 dms_p
# tris
# dms_p n2076258 dms_p
# tris
# dms_p n2076259 dms_p
# tris
# dms_p n2076260 dms_p
# tris
# dms_p n2076261 dms_p
# tris
# dms_p n2076262 dms_p
# tris
# dms_p n2076263 dms_p
# tris
# dms_p n2076264 dms_p
# tris
# dms_p n2076265 dms_p
# tris
# dms_p n2076266 dms_p
# tris
# dms_p n2076267 dms_p
# tris
# dms_p n2076268 dms_p
# tris
# dms_p n2076269 dms_p
# tris
# dms_p n2076270 dms_p
# tris
# dms_p n2076271 dms_p
# tris
# dms_p n2076272 dms_p
# tris
# dms_p n2076273 dms_p
# tris
# dms_p n2076274 dms_p
# tris
# dms_p n2076275 dms_p
# tris
# dms_p n2076276 dms_p
# tris
# dms_p n2076277 dms_p
# tris
# dms_p n2076278 dms_p
# tris
# dms_p n2076279 dms_p
# tris
# dms_p n2076280 dms_p
# tris
# dms_p n2076281 dms_p
# tris
# dms_p n2076282 dms_p
# tris
# dms_p n2076283 dms_p
# tris
# dms_p n2076284 dms_p
# tris
# dms_p n2076285 dms_p
# tris
# dms_p n2076286 dms_p
# tris
# dms_p n2076287 dms_p
# tris
# dms_p n2076288 dms_p
# tris
# dms_p n2076289 dms_p
# tris
# dms_p n2076290 dms_p
# tris
# dms_p n2076291 dms_p
# tris
# dms_p n2076292 dms_p
# tris
# dms_p n2076293 dms_p
# tris
# dms_p n2076294 dms_p
# tris
# dms_p n2076295 dms_p
# tris
# dms_p n2076296 dms_p
# tris
# dms_p n2076297 dms_p
# tris
# dms_p n2076298 dms_p
# tris
# dms_p n2076299 dms_p
# tris
# dms_p n2076300 dms_p
# tris
# dms_p n2076301 dms_p
# tris
# dms_p n2076302 dms_p
# tris
# dms_p n2076303 dms_p
# tris
# dms_p n2076304 dms_p
# tris
# dms_p n2076305 dms_p
# tris
# dms_p n2076306 dms_p
# tris
# dms_p n2076307 dms_p
# tris
# dms_p n2076308 dms_p
# tris
# dms_p n2076309 dms_p
# tris
# dms_p n2076310 dms_p
# tris
# dms_p n2076311 dms_p
# tris
# dms_p n2076312 dms_p
# tris
# dms_p n2076313 dms_p
# tris
# dms_p n2076314 dms_p
# tris
# dms_p n2076315 dms_p
# tris
# dms_p n2076316 dms_p
# tris
# dms_p n2076317 dms_p
# tris
# dms_p n2076318 dms_p
# tris
# dms_p n2076319 dms_p
# tris
# dms_p n2076320 dms_p
# tris
# dms_p n2076324 dms_p
# tris
# dms_p n2076325 dms_p
# tris
# dms_p n2076326 dms_p
# tris
# dms_p n2076327 dms_p
# tris
# dms_p n2076328 dms_p
# tris
# dms_p n2076329 dms_p
# tris
# dms_p n2076330 dms_p
# tris
# dms_p n2076331 dms_p
# tris
# dms_p n2076332 dms_p
# tris
# dms_p n2076333 dms_p
# tris
# dms_p n2076334 dms_p
# tris
# dms_p n2076335 dms_p
# tris
# dms_p n2076336 dms_p
# tris
# dms_p n2076337 dms_p
# tris
# dms_p n2076338 dms_p
# tris
# dms_p n2076339 dms_p
# tris
# dms_p n2076340 dms_p
# tris
# dms_p n2076341 dms_p
# tris
# dms_p n2076342 dms_p
# tris
# dms_p n2076343 dms_p
# tris
# dms_p n2076344 dms_p
# tris
# dms_p n2076345 dms_p
# tris
# dms_p n2076346 dms_p
# tris
# dms_p n2076347 dms_p
# tris
# dms_p n2076348 dms_p
# tris
# dms_p n2076349 dms_p
# tris
# dms_p n2076350 dms_p
# tris
# dms_p n2076351 dms_p
# tris
# dms_p n2076352 dms_p
# tris
# dms_p n2076356 dms_p
# tris
# dms_p n2076357 dms_p
# tris
# dms_p n2076358 dms_p
# tris
# dms_p n2076359 dms_p
# tris
# dms_p n2076360 dms_p
# tris
# dms_p n2076361 dms_p
# tris
# dms_p n2076362 dms_p
# tris
# dms_p n2076363 dms_p
# tris
# dms_p n2076364 dms_p
# tris
# dms_p n2076365 dms_p
# tris
# dms_p n2076366 dms_p
# tris
# dms_p n2076367 dms_p
# tris
# dms_p n2076368 dms_p
# tris
# dms_p n2076369 dms_p
# tris
# dms_p n2076370 dms_p
# tris
# dms_p n2076371 dms_p
# tris
# dms_p n2076372 dms_p
# tris
# dms_p n2076373 dms_p
# tris
# dms_p n2076374 dms_p
# tris
# dms_p n2076375 dms_p
# tris
# dms_p n2076376 dms_p
# tris
# dms_p n2076377 dms_p
# tris
# dms_p n2076378 dms_p
# tris
# dms_p n2076379 dms_p
# tris
# dms_p n2076380 dms_p
# tris
# dms_p n2076381 dms_p
# tris
# dms_p n2076382 dms_p
# tris
# dms_p n2076383 dms_p
# tris
# dms_p n2076384 dms_p
# tris
# dms_p n2076385 dms_p
# tris
# dms_p n2076386 dms_p
# tris
# dms_p n2076387 dms_p
# tris
# dms_p n2076388 dms_p
# tris
# dms_p n2076389 dms_p
# tris
# dms_p n2076390 dms_p
# tris
# dms_p n2076391 dms_p
# tris
# dms_p n2076392 dms_p
# tris
# dms_p n2076393 dms_p
# tris
# dms_p n2076394 dms_p
# tris
# dms_p n2076395 dms_p
# tris
# dms_p n2076396 dms_p
# tris
# dms_p n2076397 dms_p
# tris
# dms_p n2076398 dms_p
# tris
# dms_p n2076399 dms_p
# tris
# dms_p n2076400 dms_p
# tris
# dms_p n2076401 dms_p
# tris
# dms_p n2076402 dms_p
# tris
# dms_p n2076403 dms_p
# tris
# dms_p n2076404 dms_p
# tris
# dms_p n2076405 dms_p
# tris
# dms_p n2076406 dms_p
# tris
# dms_p n2076407 dms_p
# tris
# dms_p n2076408 dms_p
# tris
# dms_p n2076409 dms_p
# tris
# dms_p n2076410 dms_p
# tris
# dms_p n2076411 dms_p
# tris
# dms_p n2076412 dms_p
# tris
# dms_p n2076413 dms_p
# tris
# dms_p n2076414 dms_p
# tris
# dms_p n2076415 dms_p
# tris
# dms_p n2076416 dms_p
# tris
# dms_p n2076417 dms_p
# tris
# dms_p n2076418 dms_p
# tris
# dms_p n2076419 dms_p
# tris
# dms_p n2076420 dms_p
# tris
# dms_p n2076421 dms_p
# tris
# dms_p n2076422 dms_p
# tris
# dms_p n2076423 dms_p
# tris
# dms_p n2076424 dms_p
# tris
# dms_p n2076425 dms_p
# tris
# dms_p n2076426 dms_p
# tris
# dms_p n2076427 dms_p
# tris
# dms_p n2076428 dms_p
# tris
# dms_p n2076429 dms_p
# tris
# dms_p n2076430 dms_p
# tris
# dms_p n2076431 dms_p
# tris
# dms_p n2076432 dms_p
# tris
# dms_p n2076433 dms_p
# tris
# dms_p n2076434 dms_p
# tris
# dms_p n2076435 dms_p
# tris
# dms_p n2076436 dms_p
# tris
# dms_p n2076437 dms_p
# tris
# dms_p n2076438 dms_p
# tris
# dms_p n2076439 dms_p
# tris
# dms_p n2076440 dms_p
# tris
# dms_p n2076441 dms_p
# tris
# dms_p n2076442 dms_p
# tris
# dms_p n2076443 dms_p
# tris
# dms_p n2076444 dms_p
# tris
# dms_p n2076445 dms_p
# tris
# dms_p n2076446 dms_p
# tris
# dms_p n2076447 dms_p
# tris
# dms_p n2076448 dms_p
# tris
# dms_p n2076449 dms_p
# tris
# dms_p n2076450 dms_p
# tris
# dms_p n2076451 dms_p
# tris
# dms_p n2076452 dms_p
# tris
# dms_p n2076453 dms_p
# tris
# dms_p n2076454 dms_p
# tris
# dms_p n2076455 dms_p
# tris
# dms_p n2076456 dms_p
# tris
# dms_p n2076457 dms_p
# tris
# dms_p n2076458 dms_p
# tris
# dms_p n2076459 dms_p
# tris
# dms_p n2076460 dms_p
# tris
# dms_p n2076461 dms_p
# tris
# dms_p n2076462 dms_p
# tris
# dms_p n2076463 dms_p
# tris
# dms_p n2076464 dms_p
# tris
# dms_p n2076465 dms_p
# tris
# dms_p n2076466 dms_p
# tris
# dms_p n2076467 dms_p
# tris
# dms_p n2076468 dms_p
# tris
# dms_p n2076469 dms_p
# tris
# dms_p n2076470 dms_p
# tris
# dms_p n2076471 dms_p
# tris
# dms_p n2076472 dms_p
# tris
# dms_p n2076473 dms_p
# tris
# dms_p n2076474 dms_p
# tris
# dms_p n2076475 dms_p
# tris
# dms_p n2076476 dms_p
# tris
# dms_p n2076477 dms_p
# tris
# dms_p n2076479 dms_p
# tris
# dms_p n2076480 dms_p
# tris
# dms_p n2076481 dms_p
# tris
# dms_p n2076482 dms_p
# tris
# dms_p n2076483 dms_p
# tris
# dms_p n2076484 dms_p
# tris
# dms_p n2076485 dms_p
# tris
# dms_p n2076486 dms_p
# tris
# dms_p n2076487 dms_p
# tris
# dms_p n2076488 dms_p
# tris
# dms_p n2076489 dms_p
# tris
# dms_p n2076490 dms_p
# tris
# dms_p n2076491 dms_p
# tris
# dms_p n2076492 dms_p
# tris
# dms_p n2076493 dms_p
# tris
# dms_p n2076494 dms_p
# tris
# dms_p n2076495 dms_p
# tris
# dms_p n2076496 dms_p
# tris
# dms_p n2076497 dms_p
# tris
# dms_p n2076498 dms_p
# tris
# dms_p n2076499 dms_p
# tris
# dms_p n2076500 dms_p
# tris
# dms_p n2076501 dms_p
# tris
# dms_p n2076502 dms_p
# tris
# dms_p n2076503 dms_p
# tris
# dms_p n2076504 dms_p
# tris
# dms_p n2076505 dms_p
# tris
# dms_p n2076506 dms_p
# tris
# dms_p n2076507 dms_p
# tris
# dms_p n2076508 dms_p
# tris
# dms_p n2076509 dms_p
# tris
# dms_p n2076510 dms_p
# tris
# dms_p n2076511 dms_p
# tris
# dms_p n2076512 dms_p
# tris
# dms_p n2076513 dms_p
# tris
# dms_p n2076514 dms_p
# tris
# dms_p n2076515 dms_p
# tris
# dms_p n2076516 dms_p
# tris
# dms_p n2076517 dms_p
# tris
# dms_p n2076518 dms_p
# tris
# dms_p n2076519 dms_p
# tris
# dms_p n2076520 dms_p
# tris
# dms_p n2076521 dms_p
# tris
# dms_p n2076522 dms_p
# tris
# dms_p n2076523 dms_p
# tris
# dms_p n2076524 dms_p
# tris
# dms_p n2076525 dms_p
# tris
# dms_p n2076526 dms_p
# tris
# dms_p n2076527 dms_p
# tris
# dms_p n2076528 dms_p
# tris
# dms_p n2076529 dms_p
# tris
# dms_p n2076530 dms_p
# tris
# dms_p n2076531 dms_p
# tris
# dms_p n2076532 dms_p
# tris
# dms_p n2076533 dms_p
# tris
# dms_p n2076534 dms_p
# tris
# dms_p n2076535 dms_p
# tris
# dms_p n2076536 dms_p
# tris
# dms_p n2076537 dms_p
# tris
# dms_p n2076538 dms_p
# tris
# dms_p n2076539 dms_p
# tris
# dms_p n2076540 dms_p
# tris
# dms_p n2076541 dms_p
# tris
# dms_p n2076542 dms_p
# tris
# dms_p n2076543 dms_p
# tris
# dms_p n2076544 dms_p
# tris
# dms_p n2076545 dms_p
# tris
# dms_p n2076546 dms_p
# tris
# dms_p n2076547 dms_p
# tris
# dms_p n2076548 dms_p
# tris
# dms_p n2076549 dms_p
# tris
# dms_p n2076550 dms_p
# tris
# dms_p n2076551 dms_p
# tris
# dms_p n2076552 dms_p
# tris
# dms_p n2076553 dms_p
# tris
# dms_p n2076554 dms_p
# tris
# dms_p n2076555 dms_p
# tris
# dms_p n2076556 dms_p
# tris
# dms_p n2076557 dms_p
# tris
# dms_p n2076558 dms_p
# tris
# pyr_c n2076559 pyr_c
# tris
#
# lac__D_c n2076560 lac__D_c
# tris
#
# lac__D_c n2076562 lac__D_c
# tris
# lac__D_c n2076563 lac__D_c
# tris
# lac__D_c n2076564 lac__D_c
# tris
# q8h2_c n2076565 q8h2_c
# tris
#
# q8_c n2076567 q8_c
# tris
#
# q8_c n2076568 q8_c
# tris
# q8_c n2076569 q8_c
# tris
# q8_c n2076570 q8_c
# tris
# pyr_c n2076571 pyr_c
# tris
#
# lac__L_c n2076572 lac__L_c
# tris
#
# lac__L_c n2076574 lac__L_c
# tris
# lac__L_c n2076575 lac__L_c
# tris
# lac__L_c n2076576 lac__L_c
# tris
# glc__D_p n2076578 glc__D_p
# tris
#
# g6p_c n2076579 g6p_c
# tris
#
# g6p_c n2076580 g6p_c
# tris
# g6p_c n2076581 g6p_c
# tris
# g6p_c n2076582 g6p_c
# tris
# mqn8_c n2076583 mqn8_c
# tris
#
# pyr_c n2076584 pyr_c
# tris
#
# mql8_c n2076585 mql8_c
# tris
#
# None beziers divi
# tris
# None text-labels divi
# tris
# None direction-arrow-container divi
# tris
# Network has been drawn

# %% [markdown]
# # Insert additional script into SVG

# %%
path='pysvg_developed_file.svg'   #### changes in time

cssToInsert = """<defs>
        <style type="text/css"> #chart-1 { width: 100px; height: 220px; } .metric-chart { position: relative; margin: auto; } .y-axis-line-list, .x-axis-line-list, .y-axis-label-list, .x-axis-label-list, .y-axis-bar-list, .x-axis-bar-list { margin: 0; padding: 0; list-style: none; } .y-axis { position: absolute; left: 50px; top: 0px; bottom: 80px; right: auto; width: 1px; background-color: #434a54; } .y-axis-line-list { position: absolute; top: 10px; right: 0; bottom: 50px; left: 51px; } .y-axis-line-item { position: absolute; top: auto; right: 0; bottom: 0; left: 0; } .count-1 .y-axis-line-item:nth-of-type(1) { bottom: 100%; } .count-2 .y-axis-line-item:nth-of-type(1) { bottom: 50%; } .count-2 .y-axis-line-item:nth-of-type(2) { bottom: 100%; } .count-3 .y-axis-line-item:nth-of-type(1) { bottom: 33.333333333333336%; } .count-3 .y-axis-line-item:nth-of-type(2) { bottom: 66.66666666666667%; } .count-3 .y-axis-line-item:nth-of-type(3) { bottom: 100%; } .count-4 .y-axis-line-item:nth-of-type(1) { bottom: 25%; } .count-4 .y-axis-line-item:nth-of-type(2) { bottom: 50%; } .count-4 .y-axis-line-item:nth-of-type(3) { bottom: 75%; } .count-4 .y-axis-line-item:nth-of-type(4) { bottom: 100%; } .count-5 .y-axis-line-item:nth-of-type(1) { bottom: 20%; } .count-5 .y-axis-line-item:nth-of-type(2) { bottom: 40%; } .count-5 .y-axis-line-item:nth-of-type(3) { bottom: 60%; } .count-5 .y-axis-line-item:nth-of-type(4) { bottom: 80%; } .count-5 .y-axis-line-item:nth-of-type(5) { bottom: 100%; } .y-axis-line { display: block; height: 1px; background-color: #ccd1d9; } .y-axis-label-list { position: absolute; top: 10px; right: auto; bottom: 50px; left: 0; width: 40px; } .y-axis-label-item { position: absolute; top: auto; right: 0; bottom: 0; left: 0; } .count-1 .y-axis-label-item:nth-of-type(1) { bottom: 100%; } .count-2 .y-axis-label-item:nth-of-type(1) { bottom: 50%; } .count-2 .y-axis-label-item:nth-of-type(2) { bottom: 100%; } .count-3 .y-axis-label-item:nth-of-type(1) { bottom: 33.333333333333336%; } .count-3 .y-axis-label-item:nth-of-type(2) { bottom: 66.66666666666667%; } .count-3 .y-axis-label-item:nth-of-type(3) { bottom: 100%; } .count-4 .y-axis-label-item:nth-of-type(1) { bottom: 25%; } .count-4 .y-axis-label-item:nth-of-type(2) { bottom: 50%; } .count-4 .y-axis-label-item:nth-of-type(3) { bottom: 75%; } .count-4 .y-axis-label-item:nth-of-type(4) { bottom: 100%; } .count-5 .y-axis-label-item:nth-of-type(1) { bottom: 20%; } .count-5 .y-axis-label-item:nth-of-type(2) { bottom: 40%; } .count-5 .y-axis-label-item:nth-of-type(3) { bottom: 60%; } .count-5 .y-axis-label-item:nth-of-type(4) { bottom: 80%; } .count-5 .y-axis-label-item:nth-of-type(5) { bottom: 100%; } .y-axis-label { position: relative; display: block; color: #656d78; text-align: right; font-size: 12px; line-height: 1; } .h-bar-chart .y-axis-label { bottom: -6px; } .x-axis-bar-list { position: absolute; top: 0; right: 5px; bottom: 0px; left: 56px; } .x-axis-bar-item { position: absolute; top: 0px; /*high position */ right: auto; bottom: 32px; /*lowerposition */ left: 0; } .count-1 .x-axis-bar-item:nth-of-type(1) { right: 0%; left: 0%; } .x-axis-bar { position: absolute; top: auto; right: 5px; bottom: 0; left: 5px; display: block; border: 1px solid transparent; border-radius: 3px 3px 3px 3px; background-color: #4fc1e9; box-shadow: inset 0px 1px 0px rgba(255, 255, 255, 0.4); transition: all 0.15s linear; } .x-axis-bar.primary { border-color: #1f2225; background-image: -webkit-gradient(linear, 0% top, 100% top, from(#7e8692), to(#656d78)); background-image: -webkit-linear-gradient(left, color-stop(#7e8692 0%), color-stop(#656d78 100%)); background-image: -moz-linear-gradient(left, #7e8692 0%, #656d78 100%); background-image: linear-gradient(to right, #7e8692 0%, #656d78 100%); background-repeat: repeat-x; filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#ff7e8692', endColorstr='#ff656d78', GradientType=1); }</style>
   </defs>\n"""

htmlOverlayToInsert = """ <foreignObject x="0px" y="0px" width="100%" height="100%" id="overlayImageToCancelPopup" style="position: absolute;">
        <body class="overlay" xmlns="http://www.w3.org/1999/xhtml" onclick="HideTooltip()" style="position: absolute; top:0; left:0; width:100%; height:100%; z-index:-1000;">
        </body>
    </foreignObject>\n"""

htmlPopupToInsert = """<foreignObject x="0" y="0" width="420px" height="270px" id="thepopup">
        <body xmlns="http://www.w3.org/1999/xhtml" onload="HideTooltip()">
            <div style="min-width: 380px; min-height: 220px; border: 1px solid rgb(181, 135, 135); padding: 7px; background-color: rgb(255, 255, 255); box-shadow: rgba(0, 0, 0, 0.4) 4px 6px 6px 0px; text-align: left; font-size: 16px; font-family: sans-serif; color: rgb(17, 17, 17); position: relative;">
                <span id="tooltip-abbr" style="position: absolute; top: 20px; left: 20px; font-size: 16px; width: 290px;font-weight: bold;"></span>
                <span id="tooltip-name" style="position: absolute; top: 55px; left: 20px; width: 290px; font-size: 16px; word-wrap: break-word;"></span>
                <span id="tooltip-data" style="position: absolute; top: 125px; left: 20px; width: 290px; font-size: 16px; word-wrap: break-word;"></span>
                <span id="tooltip-type" style="position: absolute; top: 15px; right: 20px; font-size: 14px;  color: rgb(210, 112, 102);"></span>
                <div class="metric-chart h-bar-chart" id="chart-1" style="position: absolute; top: 40px; right: 20px; display: block; ">
                    <div class="y-axis"></div>
                    <ul class="y-axis-line-list count-5">
                        <li class="y-axis-line-item">
                        </li>
                        <li class="y-axis-line-item">
                            <span class="y-axis-line"></span>
                        </li>
                        <li class="y-axis-line-item">
                            <span class="y-axis-line"></span>
                        </li>
                        <li class="y-axis-line-item">
                            <span class="y-axis-line"></span>
                        </li>
                        <li class="y-axis-line-item">
                            <span class="y-axis-line"></span>
                        </li>
                    </ul>
                    <ul class="y-axis-label-list count-5">
                        <li class="y-axis-label-item">
                            <span class="y-axis-label">-1000</span>
                        </li>
                        <li class="y-axis-label-item">
                            <span class="y-axis-label">-500</span>
                        </li>
                        <li class="y-axis-label-item">
                            <span class="y-axis-label">0</span>
                        </li>
                        <li class="y-axis-label-item">
                            <span class="y-axis-label">500</span>
                        </li>
                        <li class="y-axis-label-item">
                            <span class="y-axis-label">1000</span>
                        </li>
                    </ul>
                    <ul class="x-axis-bar-list count-1">
                        <li class="x-axis-bar-item nested-bars">
                            <span class="x-axis-bar primary" style="top: 10px; bottom:48px;"> </span>
                        </li>
                    </ul>
                </div>
                <form id="tooltip-link" target="_blank">
                    <button style="position: absolute; bottom: 10px; left: 20px; font-size: 16px; font-weight: bold;">Open in browser</button>
                </form>
            </div>
        </body>
    </foreignObject>\n"""




scriptToInsert = """<script type="text/javascript">
        <![CDATA[
        
        function IsMetabolite(parent) {
             return parent.getElementsByClassName('node-label label').length>0;
        }

        function ShowTooltip(parent, evt) {
            HideTooltip();

            var zoom = window.outerWidth / window.innerWidth
            var isChrome = /Chrome/.test(navigator.userAgent) && /Google Inc/.test(navigator.vendor);
            if (isChrome) {
                zoom = 1;
            }

            var tooltip = document.getElementById('thepopup');

            tooltip.setAttribute("x", (evt.clientX + window.scrollX) * zoom);
            tooltip.setAttribute("y", (evt.clientY + window.scrollY) * zoom);

            var tooltipabbr = document.getElementById('tooltip-abbr');
            var tooltipname = document.getElementById('tooltip-name');
            var tooltipdata = document.getElementById('tooltip-data');
            var tooltiptype = document.getElementById('tooltip-type');
            var tooltiplink = document.getElementById('tooltip-link');

            var barParent = document.getElementById('chart-1');

            if (IsMetabolite(parent)){
                barParent.style.display = 'none';
                tooltipabbr.innerHTML = GetTextValueForPopup(parent.getElementsByClassName('node-label label')[0].textContent);
                tooltiptype.innerHTML = 'Metabolite';
                tooltipname.innerHTML =  'Name: ' + GetTextValueForPopup(parent.getAttribute("Name"));
                tooltipdata.innerHTML =  'Formula: ' + GetTextValueForPopup(parent.getAttribute("Formula"));

                if (IsScrumpyFile()){
                    var metId = ClearElementData(parent.getAttribute("id_cobrapy"));
                    tooltiplink.action = 'http://bigg.ucsd.edu/universal/metabolites/' + metId;

                }else{
                    var ell = ClearElementData(parent.getAttribute("id_metabolite"));
                    tooltiplink.action = 'http://identifiers.org/biocyc/META:' + ell;
                }
            } else {
                if (IsFVAFile(parent)) {
                    InitBar(parent, barParent);
                    barParent.style.display = 'block';
                } else {
                    barParent.style.display = 'none';
                }
                tooltipabbr.innerHTML = GetTextValueForPopup(parent.getAttribute("id"));
                tooltiptype.innerHTML = 'Reaction';
                tooltipname.innerHTML = 'Name: ' + GetTextValueForPopup(parent.getAttribute("Name"));

                tooltipdata.innerText = 'Stoichiometry: ' + GetTextValueForPopup(parent.getAttribute("Stoichiometry"));

                if (IsScrumpyFile()){
                    var ell = ClearElementData(parent.getAttribute("id"));
                    tooltiplink.action = 'http://bigg.ucsd.edu/universal/reactions/' + ell;
                } else {
                    var ell = ClearElementData(parent.getAttribute("id"));
                    tooltiplink.action = 'http://identifiers.org/biocyc/META:' + ell;
                }
            }
            tooltip.style.display = 'inline';
        }

        function IsScrumpyFile(){
            return !document.getElementById("svg2");
        }

        function GetTextValueForPopup(inputText) {
            return (inputText == '') ? 'Not specified' : ClearElementData(inputText);
        }
        
        function ClearElementData(inputElement) {
            return inputElement.replace(/_Plas/g, '').replace(/_Cyto/g, '').replace(/_Mitop/g, '').replace(/_Vaco/g, '').replace(/_tx/g, '').replace(/_c/g, '').replace(/_p/g, '').replace(/_e/g, '');
        }  
    
        function HideTooltip() {
            var tooltip = document.getElementById('thepopup');
            tooltip.style.display = 'none';
            console.log('close pressed ');
        }

        function IsFVAFile(parent) {
            if (parent.getElementsByClassName('reaction-label label').length > 0){
                innerHTML = parent.getElementsByClassName('reaction-label label')[0].textContent.trim().split(' ');
                return innerHTML.length > 2;
            }
            else {
                return false;
            }
            return false;
        }


        function InitBar(parent, barParent) {
            innerHTML = parent.getElementsByClassName('reaction-label label')[0].textContent.trim().split(' ');
            lowValue =  Math.round(innerHTML[1] / 10) * 10;
            highValue = Math.round(innerHTML[2] / 10) * 10;

            var maxFlux = parseFloat(innerHTML[2]);
            var minFlux = parseFloat(innerHTML[1]);

            var barMaxPx = 128;

            var maxValue = Math.max(Math.abs(lowValue), Math.abs(highValue));

            if (maxValue == 0) {
                maxValue = 10
            }

            var barMiddlePoint = barMaxPx / 2;
            var bottomPositionDefault = 50;
            var topPositionDefault = 10;
            var barStepsPx =  barMaxPx / 2 / maxValue;

            var top =  topPositionDefault + (maxValue - Math.abs(maxFlux)) * barStepsPx
            var bottom = bottomPositionDefault + (maxValue - Math.abs(minFlux)) * barStepsPx;
            var bar = document.getElementsByClassName('x-axis-bar primary')[0];
            bar.style.top = top + 'px';
            bar.style.bottom = bottom + 'px';
            valueStep = (maxValue * 2) / 4;

            barLinesArray = barParent.getElementsByClassName('y-axis-label');
            barLinesArray[0].innerText = Math.round(maxValue - valueStep * 4);
            barLinesArray[1].innerText = Math.round(maxValue - valueStep * 3);
            barLinesArray[2].innerText = Math.round(maxValue - valueStep * 2);
            barLinesArray[3].innerText = Math.round(maxValue - valueStep * 1);
            barLinesArray[4].innerText = Math.round(maxValue - valueStep * 0);
        }
     
        ]]>
    </script>\n"""

# %%
def InsertScripCall(source_file_path, pattern, substring):
    fh, target_file_path = mkstemp()
    with open(target_file_path, 'w') as target_file:
        with open(source_file_path, 'r') as source_file:
            for line in source_file:
                target_file.write(line.replace(pattern, substring))
    remove(source_file_path)
    move(target_file_path, source_file_path)

def IsScripHtmlInsertNeeded() :
    isInsertNeeded = True
    with open(path, 'r') as f:
        lines = f.readlines()
        f.seek(0)
        for line in lines:
            if 'overlayImageToCancelPopup' in line:
                isInsertNeeded = False
                break;
        if isInsertNeeded :
            print ('Update is completed');
        else : 
            print ('Update is not needed');
        return isInsertNeeded

def AddPopupForElementReaction(lineToChange) :
    lineNew = "onclick='ShowTooltip(this, evt)' \n " + lineToChange
    InsertScripCall(path, lineToChange, lineNew)


def AddScriptAndPopup(placeToEnd, insert_lines) :
    with open(path, 'r+') as myfile:
        lines = myfile.readlines()
        if placeToEnd :
            lines[-2:-2] = insert_lines
        else : 
            lines[1:1] = insert_lines
        myfile.seek(0)
        myfile.write(''.join(lines))
    myfile.close()

# %%
if IsScripHtmlInsertNeeded():        
    AddScriptAndPopup(False, [cssToInsert, scriptToInsert, htmlOverlayToInsert])
    AddScriptAndPopup(True, [htmlPopupToInsert])
    AddPopupForElementReaction('class="node"')
    AddPopupForElementReaction('class="reaction"')
# Out:
# Update is completed

# %%
import xml.etree.ElementTree as ET
ET.register_namespace('svg', "http://www.w3.org/2000/svg")

pathOriginalFile = file_source_path
treeOriginalFile = ET.parse(pathOriginalFile)
rootOriginalFile = treeOriginalFile.getroot()

pathPySVGFile ='pysvg_developed_file.svg'
treePySVGFile = ET.parse(pathPySVGFile)
rootPySVGFile = treePySVGFile.getroot()

for nodePySVGFile in rootPySVGFile.findall('text'):
    idElPySVGFile = nodePySVGFile.get('id')
    metIdPySVGFile = nodePySVGFile.get('id_metabolite')
    if (idElPySVGFile is not None):
        for nodeOriginalFile in rootOriginalFile.findall('{http://www.w3.org/2000/svg}text'):
            idElOriginalFile = nodeOriginalFile.get('id')
            if(idElOriginalFile == idElPySVGFile):
                metIdOriginalFile = nodeOriginalFile.get('id_metabolite')
                if (metIdOriginalFile is not None):
                    if (metIdPySVGFile is not None):
                        nodePySVGFile.set('id_metabolite', str(metIdOriginalFile))
for nodePySVGFile in rootPySVGFile.findall('g'):
    idElPySVGFile = nodePySVGFile.get('id')
    metIdPySVGFile = nodePySVGFile.get('id_metabolite')
    if (idElPySVGFile is not None):
        for nodeOriginalFile in rootOriginalFile.findall('{http://www.w3.org/2000/svg}g'):
            idElOriginalFile = nodeOriginalFile.get('id')
            if(idElOriginalFile == idElPySVGFile):
                metIdOriginalFile = nodeOriginalFile.get('id_metabolite')
                if (metIdOriginalFile is not None):
                    if (metIdPySVGFile is not None):
                        nodePySVGFile.set('id_metabolite', str(metIdOriginalFile))
    
treePySVGFile.write(str(prod) + "_" + str(subst) + "_" + str(count) + '.svg') 
os.remove('pysvg_developed_file.svg')
